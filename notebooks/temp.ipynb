# %%
import os
os.chdir("/".join(os.getcwd().split("/")[0:-1]))
print("working dir", os.getcwd())
# Out:
# working dir /home/tales/dev/mdc_analysis

# %%
from src.dao.csv_dao import load_user_gps_csv, fill_data_missing_ts
from src.plot.stop_region_plot import plot_users_stop_region

# %%
def mdc_user_gps_to_137_format(user_gps_data):
    user_gps_data

# %%
user_gps = load_user_gps_csv(6171)

# %%
user_gps[["time", "latitude", "longitude"]][25 : 30]
# Out:
#             time  latitude  longitude
# 2644  1270658961   46.4541    6.86672
# 578   1270659335   46.4540    6.86630
# 2598  1270659345   46.4540    6.86648
# 506   1270659355   46.4541    6.86656
# 1350  1270659365   46.4540    6.86656

# %%
d = fill_data_missing_ts(user_gps[25 : 30])

# %%
#d

# %%
from bokeh.io import output_notebook, show
output_notebook()

p = plot_users_stop_region([5448, 5989], width=900, height=600)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="76bf1076-e7bf-4bf0-8c34-05c7eaf02e70">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a2ebe30f-6095-4134-9d1a-03038c504509"></div>
