# %% [markdown]
# # Using CategoryMapper (Google Places)

# %%
import os

os.chdir("/home/tales/dev/master/mdc_analysis/")
print("working dir", os.getcwd())

import pandas as pd
import matplotlib.pyplot as plt
import json
import urllib.request

from src.poi_grabber import google_places
from src.dao import csv_dao
from src.entity.stop_region import StopRegionGroup

from src.utils.type_hierarchy_analysis import parent, children, relations_freq, occurrences_in_visited_pois
# Out:
# working dir /home/tales/dev/master/mdc_analysis
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-d97ca276e993> in <module>()
#      13 from src.entity.stop_region import StopRegionGroup
#      14
# ---> 15 from src.utils.type_hierarchy_analysis import parent, children, relations_freq, occurrences_in_visited_pois
#
# ImportError: cannot import name 'occurrences_in_visited_pois'

# %%
url = "http://127.0.0.1:5000/stop_regions_group"
response = urllib.request.urlopen(url)
users_tags_sequence = json.loads(response.read())

# %%
# users = os.listdir("outputs/stop_regions/")
# users.reverse()

# for user_id in users:
#     print("Loading user {} data".format(user_id))
#     users_tags_sequence[user_id] = StopRegionGroup(csv_dao.stop_region_sequence(user_id), 
#                                                     agglutinate_stop_regions=True).sequence_stop_region_tags()["tag"].tolist()

# %%
pois = google_places.load_all_google_places_data(valid_pois=True)

# %%
pois_freq = pd.read_csv("outputs/taxonomy/google_places/pois_frequencies.csv").set_index("type")
pois_freq.head()
# Out:
#                  index  freq_all  freq_visited  prop_all  prop_visited
# type
# store                0     11788          9864     0.282         0.201
# food                 1      7858          8970     0.188         0.183
# restaurant           2      4830          5327     0.116         0.109
# health               3      8062          4132     0.193         0.084
# transit_station      4      1688          3407     0.040         0.070

# %% [markdown]
# # Automatic Category Hierarchy

# %% [markdown]
# ### Relations

# %%
relations_all_freq = relations_freq(pois)

# %%
relations_all_freq.head(12)
# Out:
#                 parent           category   freq
# 0                    .      establishment  40794
# 213      establishment  point_of_interest  40517
# 570  point_of_interest              store  11486
# 571  point_of_interest             health   6778
# 572  point_of_interest               food   4740
# 239               food         restaurant   4501
# 663         restaurant               NULL   3779
# 738              store               food   2874
# 573  point_of_interest            finance   2865
# 339             health               NULL   2780
# 340             health             doctor   2505
# 178             doctor               NULL   2364

# %% [markdown]
# # Using CategoryMapper

# %%
from src.taxonomy.category_mapping import CategoryMapper
from src.exceptions.exceptions import NoCategoryMatched
from src.utils.others import remove_list_elements

# %%
categ_mapper = CategoryMapper()

# %%
len(pois)
# Out:
# 41739

# %% [markdown]
# ## Mapping each POI from <font color="red">all</font> POIs

# %%
mapped_types = []
categ_not_found = []

counter = 0

for i, poi in pois.iterrows():
    counter += 1
    if counter % 5000 == 0 or counter == len(pois):
        print("{}%".format(round(counter * 100 / len(pois), 2)))
    
    types = remove_list_elements(poi["types"], elements=['premise', 'point_of_interest', 'establishment'])
    
    try:
        category = categ_mapper.map_categ(types)
        mapped_types.append({"types": types, "category": category})
        
    except NoCategoryMatched:
        categ_not_found.append(types)
# Out:
# 16.77%
# 33.54%
# 50.31%
# 67.08%
# 83.85%
# 100.0%

# %%
print("Types not mapped to any category")
pd.Series(categ_not_found).astype(str).value_counts()
# Out:
# Types not mapped to any category
# ['park']                            211
# ['laundry']                         165
# ['library']                         143
# ['shopping_mall']                   134
# ['car_rental']                      101
# ['movie_theater']                    93
# ['cemetery']                         53
# ['police']                           45
# ['car_wash']                         36
# ['moving_company']                   20
# ['roofing_contractor']               16
# ['amusement_park']                   14
# ['stadium']                          13
# ['bowling_alley']                     6
# ['courthouse']                        5
# ['natural_feature']                   4
# ['car_rental', 'moving_company']      2
# ['park', 'laundry']                   2
# ['movie_rental']                      1
# ['route']                             1
# ['aquarium']                          1
# ['moving_company', 'laundry']         1
# dtype: int64

# %%
import ast 

for types in pd.Series(categ_not_found).astype(str).value_counts().index:
    print("\n-----")
    print("types:", types)
    print()
    
    for a_type in ast.literal_eval(types):
        print(">>>", a_type)
        print("visited :", occurrences_in_visited_pois(a_type))
        print("all     :", occurrences_in_all_pois(a_type))

        print("PARENT")
        print(parent(a_type, relations_all_freq))
        print("\nCHILDREN")
        print(children(a_type, relations_all_freq))
        print()

#parent("point_of_interest")
# Out:
# -----
# types: ['park']
#
# >>> park
# visited : {'freq': 591, 'prop': 0.012}
# all     : {'freq': 260, 'prop': 0.006}
# PARENT
#                  parent category  freq      prop
# 595   point_of_interest     park   174  0.669231
# 648             premise     park    44  0.169231
# 461             lodging     park    23  0.088462
# 768               store     park     5  0.019231
# 300  general_contractor     park     5  0.019231
# 683          restaurant     park     2  0.007692
# 424             laundry     park     2  0.007692
# 283     furniture_store     park     2  0.007692
# 698             rv_park     park     1  0.003846
# 267                food     park     1  0.003846
# 101                cafe     park     1  0.003846
#
# CHILDREN
#     parent        category  freq      prop
# 526   park            NULL   219  0.842308
# 527   park      campground    21  0.080769
# 528   park         premise     4  0.015385
# 529   park   travel_agency     4  0.015385
# 531   park         florist     2  0.007692
# 530   park  amusement_park     2  0.007692
# 539   park             zoo     1  0.003846
# 538   park      shoe_store     1  0.003846
# 537   park         parking     1  0.003846
# 536   park          museum     1  0.003846
# 535   park             gym     1  0.003846
# 534   park  clothing_store     1  0.003846
# 533   park        cemetery     1  0.003846
# 532   park        car_wash     1  0.003846
#
#
# -----
# types: ['laundry']
#
# >>> laundry
# visited : {'freq': 86, 'prop': 0.002}
# all     : {'freq': 195, 'prop': 0.005}
# PARENT
#                  parent category  freq      prop
# 597   point_of_interest  laundry   171  0.876923
# 385    home_goods_store  laundry     9  0.046154
# 766               store  laundry     7  0.035897
# 305  general_contractor  laundry     3  0.015385
# 735             storage  laundry     2  0.010256
# 266                food  laundry     1  0.005128
# 286     furniture_store  laundry     1  0.005128
# 160      clothing_store  laundry     1  0.005128
#
# CHILDREN
#       parent          category  freq      prop
# 420  laundry              NULL   177  0.907692
# 421  laundry    clothing_store     4  0.020513
# 422  laundry   furniture_store     4  0.020513
# 423  laundry    moving_company     3  0.015385
# 424  laundry              park     2  0.010256
# 429  laundry           parking     1  0.005128
# 428  laundry  home_goods_store     1  0.005128
# 427  laundry            health     1  0.005128
# 426  laundry           finance     1  0.005128
# 425  laundry               bar     1  0.005128
#
#
# -----
# types: ['library']
#
# >>> library
# visited : {'freq': 179, 'prop': 0.004}
# all     : {'freq': 151, 'prop': 0.004}
# PARENT
#                 parent category  freq      prop
# 599  point_of_interest  library   143  0.947020
# 74          book_store  library     3  0.019868
# 821         university  library     3  0.019868
# 780              store  library     1  0.006623
# 509             museum  library     1  0.006623
#
# CHILDREN
#       parent    category  freq      prop
# 436  library        NULL   150  0.993377
# 437  library  book_store     1  0.006623
#
#
# -----
# types: ['shopping_mall']
#
# >>> shopping_mall
# visited : {'freq': 124, 'prop': 0.003}
# all     : {'freq': 169, 'prop': 0.004}
# PARENT
#                      parent       category  freq      prop
# 600       point_of_interest  shopping_mall   134  0.792899
# 151          clothing_store  shopping_mall    12  0.071006
# 767                   store  shopping_mall     7  0.041420
# 794             supermarket  shopping_mall     2  0.011834
# 175        department_store  shopping_mall     2  0.011834
# 448            liquor_store  shopping_mall     1  0.005917
# 544                 parking  shopping_mall     1  0.005917
# 327  grocery_or_supermarket  shopping_mall     1  0.005917
# 289         furniture_store  shopping_mall     1  0.005917
# 293             gas_station  shopping_mall     1  0.005917
# 647             post_office  shopping_mall     1  0.005917
# 434                  lawyer  shopping_mall     1  0.005917
# 402        home_goods_store  shopping_mall     1  0.005917
# 58                      bar  shopping_mall     1  0.005917
# 662      real_estate_agency  shopping_mall     1  0.005917
# 657                 premise  shopping_mall     1  0.005917
# 554                pharmacy  shopping_mall     1  0.005917
#
# CHILDREN
#             parent          category  freq      prop
# 715  shopping_mall              NULL   162  0.958580
# 716  shopping_mall    clothing_store     3  0.017751
# 717  shopping_mall  department_store     1  0.005917
# 718  shopping_mall   furniture_store     1  0.005917
# 719  shopping_mall        shoe_store     1  0.005917
# 720  shopping_mall             store     1  0.005917
#
#
# -----
# types: ['car_rental']
#
# >>> car_rental
# visited : {'freq': 141, 'prop': 0.003}
# all     : {'freq': 118, 'prop': 0.003}
# PARENT
#                 parent    category  freq      prop
# 603  point_of_interest  car_rental   103  0.872881
# 121         car_repair  car_rental     4  0.033898
# 108         car_dealer  car_rental     2  0.016949
# 260               food  car_rental     2  0.016949
# 800         taxi_stand  car_rental     2  0.016949
# 501     moving_company  car_rental     2  0.016949
# 813      travel_agency  car_rental     1  0.008475
# 471            lodging  car_rental     1  0.008475
# 136           car_wash  car_rental     1  0.008475
#
# CHILDREN
#          parent            category  freq      prop
# 112  car_rental                NULL   113  0.957627
# 113  car_rental       travel_agency     3  0.025424
# 115  car_rental  real_estate_agency     1  0.008475
# 114  car_rental          car_dealer     1  0.008475
#
#
# -----
# types: ['movie_theater']
#
# >>> movie_theater
# visited : {'freq': 75, 'prop': 0.002}
# all     : {'freq': 98, 'prop': 0.002}
# PARENT
#                 parent       category  freq      prop
# 604  point_of_interest  movie_theater    95  0.969388
# 830         university  movie_theater     1  0.010204
# 688         restaurant  movie_theater     1  0.010204
# 401   home_goods_store  movie_theater     1  0.010204
#
# CHILDREN
#             parent           category  freq      prop
# 497  movie_theater               NULL    95  0.969388
# 498  movie_theater                bar     2  0.020408
# 499  movie_theater  electronics_store     1  0.010204
#
#
# -----
# types: ['cemetery']
#
# >>> cemetery
# visited : {'freq': 85, 'prop': 0.002}
# all     : {'freq': 55, 'prop': 0.001}
# PARENT
#                 parent  category  freq      prop
# 615  point_of_interest  cemetery    41  0.745455
# 650            premise  cemetery    12  0.218182
# 228            finance  cemetery     1  0.018182
# 533               park  cemetery     1  0.018182
#
# CHILDREN
#        parent category  freq  prop
# 138  cemetery     NULL    55   1.0
#
#
# -----
# types: ['police']
#
# >>> police
# visited : {'freq': 62, 'prop': 0.001}
# all     : {'freq': 50, 'prop': 0.001}
# PARENT
#                 parent category  freq  prop
# 613  point_of_interest   police    49  0.98
# 234       fire_station   police     1  0.02
#
# CHILDREN
#      parent category  freq  prop
# 639  police     NULL    49  0.98
# 640  police  premise     1  0.02
#
#
# -----
# types: ['car_wash']
#
# >>> car_wash
# visited : {'freq': 82, 'prop': 0.002}
# all     : {'freq': 93, 'prop': 0.002}
# PARENT
#                 parent  category  freq      prop
# 614  point_of_interest  car_wash    45  0.483871
# 252               food  car_wash    18  0.193548
# 118         car_repair  car_wash    16  0.172043
# 88                cafe  car_wash    10  0.107527
# 32              bakery  car_wash     2  0.021505
# 397   home_goods_store  car_wash     1  0.010753
# 532               park  car_wash     1  0.010753
#
# CHILDREN
#        parent                category  freq      prop
# 131  car_wash                    NULL    41  0.440860
# 132  car_wash       convenience_store    25  0.268817
# 133  car_wash             gas_station    13  0.139785
# 134  car_wash              car_dealer     8  0.086022
# 135  car_wash  grocery_or_supermarket     5  0.053763
# 136  car_wash              car_rental     1  0.010753
#
#
# -----
# types: ['moving_company']
#
# >>> moving_company
# visited : {'freq': 126, 'prop': 0.003}
# all     : {'freq': 92, 'prop': 0.002}
# PARENT
#                  parent        category  freq      prop
# 730             storage  moving_company    59  0.641304
# 619   point_of_interest  moving_company    22  0.239130
# 423             laundry  moving_company     3  0.032609
# 394    home_goods_store  moving_company     2  0.021739
# 308  general_contractor  moving_company     2  0.021739
# 781               store  moving_company     1  0.010870
# 287     furniture_store  moving_company     1  0.010870
# 232             finance  moving_company     1  0.010870
# 128          car_repair  moving_company     1  0.010870
#
# CHILDREN
#              parent           category  freq      prop
# 500  moving_company               NULL    88  0.956522
# 501  moving_company         car_rental     2  0.021739
# 503  moving_company  electronics_store     1  0.010870
# 502  moving_company               bank     1  0.010870
#
#
# -----
# types: ['roofing_contractor']
#
# >>> roofing_contractor
# visited : {'freq': 14, 'prop': 0.0}
# all     : {'freq': 38, 'prop': 0.001}
# PARENT
#                  parent            category  freq      prop
# 621   point_of_interest  roofing_contractor    16  0.421053
# 382    home_goods_store  roofing_contractor    12  0.315789
# 301  general_contractor  roofing_contractor     5  0.131579
# 771               store  roofing_contractor     3  0.078947
# 130          car_repair  roofing_contractor     1  0.026316
# 525             painter  roofing_contractor     1  0.026316
#
# CHILDREN
#                  parent        category  freq      prop
# 692  roofing_contractor            NULL    29  0.763158
# 693  roofing_contractor         plumber     7  0.184211
# 694  roofing_contractor  hardware_store     2  0.052632
#
#
# -----
# types: ['amusement_park']
#
# >>> amusement_park
# visited : {'freq': 86, 'prop': 0.002}
# all     : {'freq': 20, 'prop': 0.0}
# PARENT
#                 parent        category  freq  prop
# 620  point_of_interest  amusement_park    16  0.80
# 530               park  amusement_park     2  0.10
# 469            lodging  amusement_park     1  0.05
# 330                gym  amusement_park     1  0.05
#
# CHILDREN
#             parent    category  freq  prop
# 10  amusement_park        NULL    16  0.80
# 11  amusement_park  campground     2  0.10
# 12  amusement_park      museum     1  0.05
# 13  amusement_park         zoo     1  0.05
#
#
# -----
# types: ['stadium']
#
# >>> stadium
# visited : {'freq': 636, 'prop': 0.013}
# all     : {'freq': 13, 'prop': 0.0}
# PARENT
#                 parent category  freq      prop
# 625  point_of_interest  stadium     8  0.615385
# 651            premise  stadium     5  0.384615
#
# CHILDREN
#       parent category  freq  prop
# 729  stadium     NULL    13   1.0
#
#
# -----
# types: ['bowling_alley']
#
# >>> bowling_alley
# visited : {'freq': 27, 'prop': 0.001}
# all     : {'freq': 14, 'prop': 0.0}
# PARENT
#                 parent       category  freq      prop
# 628  point_of_interest  bowling_alley     6  0.428571
# 542            parking  bowling_alley     2  0.142857
# 682         restaurant  bowling_alley     2  0.142857
# 52                 bar  bowling_alley     2  0.142857
# 284    furniture_store  bowling_alley     1  0.071429
# 487      meal_takeaway  bowling_alley     1  0.071429
#
# CHILDREN
#            parent category  freq  prop
# 79  bowling_alley     NULL    14   1.0
#
#
# -----
# types: ['courthouse']
#
# >>> courthouse
# visited : {'freq': 2, 'prop': 0.0}
# all     : {'freq': 7, 'prop': 0.0}
# PARENT
#                 parent    category  freq  prop
# 626  point_of_interest  courthouse     7   1.0
#
# CHILDREN
#          parent category  freq  prop
# 168  courthouse     NULL     7   1.0
#
#
# -----
# types: ['natural_feature']
#
# >>> natural_feature
# visited : {'freq': 11, 'prop': 0.0}
# all     : {'freq': 7, 'prop': 0.0}
# PARENT
#                 parent         category  freq  prop
# 627  point_of_interest  natural_feature     7   1.0
#
# CHILDREN
#               parent category  freq      prop
# 511  natural_feature     NULL     4  0.571429
# 513  natural_feature  lodging     1  0.142857
# 512  natural_feature     food     1  0.142857
# 514  natural_feature    store     1  0.142857
#
#
# -----
# types: ['car_rental', 'moving_company']
#
# >>> car_rental
# visited : {'freq': 141, 'prop': 0.003}
# all     : {'freq': 118, 'prop': 0.003}
# PARENT
#                 parent    category  freq      prop
# 603  point_of_interest  car_rental   103  0.872881
# 121         car_repair  car_rental     4  0.033898
# 108         car_dealer  car_rental     2  0.016949
# 260               food  car_rental     2  0.016949
# 800         taxi_stand  car_rental     2  0.016949
# 501     moving_company  car_rental     2  0.016949
# 813      travel_agency  car_rental     1  0.008475
# 471            lodging  car_rental     1  0.008475
# 136           car_wash  car_rental     1  0.008475
#
# CHILDREN
#          parent            category  freq      prop
# 112  car_rental                NULL   113  0.957627
# 113  car_rental       travel_agency     3  0.025424
# 115  car_rental  real_estate_agency     1  0.008475
# 114  car_rental          car_dealer     1  0.008475
#
# >>> moving_company
# visited : {'freq': 126, 'prop': 0.003}
# all     : {'freq': 92, 'prop': 0.002}
# PARENT
#                  parent        category  freq      prop
# 730             storage  moving_company    59  0.641304
# 619   point_of_interest  moving_company    22  0.239130
# 423             laundry  moving_company     3  0.032609
# 394    home_goods_store  moving_company     2  0.021739
# 308  general_contractor  moving_company     2  0.021739
# 781               store  moving_company     1  0.010870
# 287     furniture_store  moving_company     1  0.010870
# 232             finance  moving_company     1  0.010870
# 128          car_repair  moving_company     1  0.010870
#
# CHILDREN
#              parent           category  freq      prop
# 500  moving_company               NULL    88  0.956522
# 501  moving_company         car_rental     2  0.021739
# 503  moving_company  electronics_store     1  0.010870
# 502  moving_company               bank     1  0.010870
#
#
# -----
# types: ['park', 'laundry']
#
# >>> park
# visited : {'freq': 591, 'prop': 0.012}
# all     : {'freq': 260, 'prop': 0.006}
# PARENT
#                  parent category  freq      prop
# 595   point_of_interest     park   174  0.669231
# 648             premise     park    44  0.169231
# 461             lodging     park    23  0.088462
# 768               store     park     5  0.019231
# 300  general_contractor     park     5  0.019231
# 683          restaurant     park     2  0.007692
# 424             laundry     park     2  0.007692
# 283     furniture_store     park     2  0.007692
# 698             rv_park     park     1  0.003846
# 267                food     park     1  0.003846
# 101                cafe     park     1  0.003846
#
# CHILDREN
#     parent        category  freq      prop
# 526   park            NULL   219  0.842308
# 527   park      campground    21  0.080769
# 528   park         premise     4  0.015385
# 529   park   travel_agency     4  0.015385
# 531   park         florist     2  0.007692
# 530   park  amusement_park     2  0.007692
# 539   park             zoo     1  0.003846
# 538   park      shoe_store     1  0.003846
# 537   park         parking     1  0.003846
# 536   park          museum     1  0.003846
# 535   park             gym     1  0.003846
# 534   park  clothing_store     1  0.003846
# 533   park        cemetery     1  0.003846
# 532   park        car_wash     1  0.003846
#
# >>> laundry
# visited : {'freq': 86, 'prop': 0.002}
# all     : {'freq': 195, 'prop': 0.005}
# PARENT
#                  parent category  freq      prop
# 597   point_of_interest  laundry   171  0.876923
# 385    home_goods_store  laundry     9  0.046154
# 766               store  laundry     7  0.035897
# 305  general_contractor  laundry     3  0.015385
# 735             storage  laundry     2  0.010256
# 266                food  laundry     1  0.005128
# 286     furniture_store  laundry     1  0.005128
# 160      clothing_store  laundry     1  0.005128
#
# CHILDREN
#       parent          category  freq      prop
# 420  laundry              NULL   177  0.907692
# 421  laundry    clothing_store     4  0.020513
# 422  laundry   furniture_store     4  0.020513
# 423  laundry    moving_company     3  0.015385
# 424  laundry              park     2  0.010256
# 429  laundry           parking     1  0.005128
# 428  laundry  home_goods_store     1  0.005128
# 427  laundry            health     1  0.005128
# 426  laundry           finance     1  0.005128
# 425  laundry               bar     1  0.005128
#
#
# -----
# types: ['movie_rental']
#
# >>> movie_rental
# visited : {'freq': 9, 'prop': 0.0}
# all     : {'freq': 40, 'prop': 0.001}
# PARENT
#                 parent      category  freq   prop
# 198  electronics_store  movie_rental    32  0.800
# 75          book_store  movie_rental     2  0.050
# 773              store  movie_rental     2  0.050
# 400   home_goods_store  movie_rental     1  0.025
# 635  point_of_interest  movie_rental     1  0.025
# 553           pharmacy  movie_rental     1  0.025
# 161     clothing_store  movie_rental     1  0.025
#
# CHILDREN
#            parent           category  freq   prop
# 493  movie_rental               NULL    29  0.725
# 494  movie_rental         book_store     9  0.225
# 496  movie_rental              store     1  0.025
# 495  movie_rental  electronics_store     1  0.025
#
#
# -----
# types: ['route']
#
# >>> route
# visited : {'freq': 0, 'prop': 0.0}
# all     : {'freq': 1, 'prop': 0.0}
# PARENT
#                 parent category  freq  prop
# 638  point_of_interest    route     1   1.0
#
# CHILDREN
#     parent category  freq  prop
# 695  route     NULL     1   1.0
#
#
# -----
# types: ['aquarium']
#
# >>> aquarium
# visited : {'freq': 0, 'prop': 0.0}
# all     : {'freq': 1, 'prop': 0.0}
# PARENT
#                 parent  category  freq  prop
# 632  point_of_interest  aquarium     1   1.0
#
# CHILDREN
#       parent category  freq  prop
# 14  aquarium     NULL     1   1.0
#
#
# -----
# types: ['moving_company', 'laundry']
#
# >>> moving_company
# visited : {'freq': 126, 'prop': 0.003}
# all     : {'freq': 92, 'prop': 0.002}
# PARENT
#                  parent        category  freq      prop
# 730             storage  moving_company    59  0.641304
# 619   point_of_interest  moving_company    22  0.239130
# 423             laundry  moving_company     3  0.032609
# 394    home_goods_store  moving_company     2  0.021739
# 308  general_contractor  moving_company     2  0.021739
# 781               store  moving_company     1  0.010870
# 287     furniture_store  moving_company     1  0.010870
# 232             finance  moving_company     1  0.010870
# 128          car_repair  moving_company     1  0.010870
#
# CHILDREN
#              parent           category  freq      prop
# 500  moving_company               NULL    88  0.956522
# 501  moving_company         car_rental     2  0.021739
# 503  moving_company  electronics_store     1  0.010870
# 502  moving_company               bank     1  0.010870
#
# >>> laundry
# visited : {'freq': 86, 'prop': 0.002}
# all     : {'freq': 195, 'prop': 0.005}
# PARENT
#                  parent category  freq      prop
# 597   point_of_interest  laundry   171  0.876923
# 385    home_goods_store  laundry     9  0.046154
# 766               store  laundry     7  0.035897
# 305  general_contractor  laundry     3  0.015385
# 735             storage  laundry     2  0.010256
# 266                food  laundry     1  0.005128
# 286     furniture_store  laundry     1  0.005128
# 160      clothing_store  laundry     1  0.005128
#
# CHILDREN
#       parent          category  freq      prop
# 420  laundry              NULL   177  0.907692
# 421  laundry    clothing_store     4  0.020513
# 422  laundry   furniture_store     4  0.020513
# 423  laundry    moving_company     3  0.015385
# 424  laundry              park     2  0.010256
# 429  laundry           parking     1  0.005128
# 428  laundry  home_goods_store     1  0.005128
# 427  laundry            health     1  0.005128
# 426  laundry           finance     1  0.005128
# 425  laundry               bar     1  0.005128

# %%
parent("liquor_store")

# %%
categories["level_extra"] = ["natural_feature"]

# %%
categories["level_extra"] = ["natural_feature"]
categories["level_extra"].append("laundry")
categories["level_extra"].append("library")

categories

# %%
with open('outputs/taxonomy/google_places/categories.csv', 'w') as outfile:
    json.dump(categories, outfile)

# %%
def occurrences_in_all_pois(term, pois_types=pois["types"], round_n=3):
    occurrences = pois_types.apply(lambda types: term in types).value_counts()
    try:
        freq = occurrences.loc[True]
    except KeyError:
        freq = 0

    prop = freq / len(pois_types)

    if round_n:
        prop = round(prop, round_n)

    return {"freq": freq, "prop": prop}
