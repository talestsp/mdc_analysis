# %% [markdown]
# # Using CategoryMapper (Google Places)

# %%
import os

os.chdir("/home/tales/dev/master/mdc_analysis/")
print("working dir", os.getcwd())

import pandas as pd
import matplotlib.pyplot as plt
import json
import urllib.request

from src.poi_grabber import google_places
from src.dao import csv_dao, objects_dao
from src.entity.stop_region import StopRegionGroup

from src.utils.type_hierarchy_analysis import parent, children, relations_freq, occurrences_in_visited_pois, occurrences_in_all_pois
# Out:
# working dir /home/tales/dev/master/mdc_analysis

# %%
def get_users_tags_sequence():
    url = "http://127.0.0.1:5000/stop_regions_group"
    response = urllib.request.urlopen(url)
    return json.loads(response.read())

def load_users_tags_sequence():
    with open('outputs/users_tags_sequence.json') as json_file:
        return json.load(json_file)
    
users_tags_sequence = load_users_tags_sequence()

# %%
# users = os.listdir("outputs/stop_regions/")
# users.reverse()

# for user_id in users:
#     print("Loading user {} data".format(user_id))
#     users_tags_sequence[user_id] = StopRegionGroup(csv_dao.stop_region_sequence(user_id), 
#                                                     agglutinate_stop_regions=True).sequence_stop_region_tags()["tag"].tolist()

# %%
pois = google_places.load_all_google_places_data(valid_pois=True)

# %%
pois_freq = pd.read_csv("outputs/taxonomy/google_places/pois_frequencies.csv").set_index("type")
pois_freq.head()
# Out:
#                  index  freq_all  freq_visited  prop_all  prop_visited
# type
# store                0     11807          9864     0.282         0.201
# food                 1      7873          8970     0.188         0.183
# restaurant           2      4831          5327     0.116         0.109
# health               3      8089          4132     0.193         0.084
# transit_station      4      1691          3407     0.040         0.070

# %% [markdown]
# # Automatic Category Hierarchy

# %% [markdown]
# ### Relations

# %%
relations_all_freq = relations_freq(pois)

# %%
relations_all_freq.head(12)
# Out:
#                 parent           category   freq
# 0                    .      establishment  40876
# 213      establishment  point_of_interest  40597
# 570  point_of_interest              store  11508
# 571  point_of_interest             health   6806
# 572  point_of_interest               food   4739
# 239               food         restaurant   4501
# 663         restaurant               NULL   3779
# 739              store               food   2888
# 573  point_of_interest            finance   2872
# 340             health               NULL   2776
# 341             health             doctor   2520
# 178             doctor               NULL   2379

# %%
print(occurrences_in_visited_pois("parking", users_tags_sequence))
print(occurrences_in_all_pois("parking", pois["types"]))
# Out:
# {'freq': 631, 'prop': 0.013}
# {'freq': 412, 'prop': 0.01}

# %%
print(occurrences_in_visited_pois("natural_feature", users_tags_sequence))
print(occurrences_in_all_pois("natural_feature", pois["types"]))
# Out:
# {'freq': 11, 'prop': 0.0}
# {'freq': 7, 'prop': 0.0}

# %% [markdown]
# # Using CategoryMapper

# %%
from src.taxonomy.category_mapping import CategoryMapper
from src.exceptions.exceptions import NoCategoryMatched
from src.utils.others import remove_list_elements

# %%
categ_mapper = CategoryMapper()

# %%
len(pois)
# Out:
# 41819

# %% [markdown]
# ## Mapping each POI from <font color="red">all</font> POIs

# %%
mapped_types = []
categ_not_found = []

counter = 0

for i, poi in pois.iterrows():
    counter += 1
    if counter % 5000 == 0 or counter == len(pois):
        print("{}%".format(round(counter * 100 / len(pois), 2)))
    
    types = remove_list_elements(poi["types"], elements=['premise', 'point_of_interest', 'establishment'])
        
    try:
        category = categ_mapper.map_categ(types, method="most_specific", logs=False)
        mapped_types.append({"types": types, "category": category})
        
    except NoCategoryMatched:
        mapped_types.append({"types": types, "category": "NoCategoryMatched"})
        categ_not_found.append(types)
# Out:
# 11.96%
# 23.91%
# 35.87%
# 47.83%
# 59.78%
# 71.74%
# 83.69%
# 95.65%
# 100.0%

# %%
print(len(mapped_types))
print(len(categ_not_found))
# Out:
# 41819
# 815

# %%
print("Types not mapped to any category")
pd.Series(categ_not_found).astype(str).value_counts()
# Out:
# Types not mapped to any category
# ['park']                            212
# ['shopping_mall']                   134
# ['car_rental']                      100
# ['movie_theater']                    94
# ['funeral_home']                     58
# ['cemetery']                         53
# ['police']                           47
# ['car_wash']                         36
# ['moving_company']                   19
# ['roofing_contractor']               16
# ['amusement_park']                   14
# ['stadium']                          13
# ['airport']                           9
# ['courthouse']                        5
# ['car_rental', 'moving_company']      2
# ['movie_rental']                      1
# ['aquarium']                          1
# ['route']                             1
# dtype: int64

# %%
import ast 

for types in pd.Series(categ_not_found).astype(str).value_counts().index:
    print("\n-----")
    print("types:", types)
    print()
    
    for a_type in ast.literal_eval(types):
        print(">>>", a_type)
        print("visited :", occurrences_in_visited_pois(a_type, users_tags_sequence))
        print("all     :", occurrences_in_all_pois(a_type, pois["types"]))

        print("PARENT")
        print(parent(a_type, relations_all_freq))
        print("\nCHILDREN")
        print(children(a_type, relations_all_freq))
        print()

#parent("point_of_interest")
# Out:
# -----
# types: ['park']
#
# >>> park
# visited : {'freq': 591, 'prop': 0.012}
# all     : {'freq': 260, 'prop': 0.006}
# PARENT
#                  parent category  freq      prop
# 595   point_of_interest     park   175  0.673077
# 648             premise     park    44  0.169231
# 463             lodging     park    23  0.088462
# 301  general_contractor     park     5  0.019231
# 770               store     park     4  0.015385
# 683          restaurant     park     2  0.007692
# 283     furniture_store     park     2  0.007692
# 425             laundry     park     2  0.007692
# 698             rv_park     park     1  0.003846
# 101                cafe     park     1  0.003846
# 267                food     park     1  0.003846
#
# CHILDREN
#     parent        category  freq      prop
# 527   park            NULL   220  0.846154
# 528   park      campground    21  0.080769
# 530   park   travel_agency     4  0.015385
# 529   park         premise     4  0.015385
# 532   park         florist     2  0.007692
# 531   park  amusement_park     2  0.007692
# 539   park             zoo     1  0.003846
# 538   park         parking     1  0.003846
# 537   park          museum     1  0.003846
# 536   park             gym     1  0.003846
# 535   park  clothing_store     1  0.003846
# 534   park        cemetery     1  0.003846
# 533   park        car_wash     1  0.003846
#
#
# -----
# types: ['shopping_mall']
#
# >>> shopping_mall
# visited : {'freq': 124, 'prop': 0.003}
# all     : {'freq': 169, 'prop': 0.004}
# PARENT
#                      parent       category  freq      prop
# 600       point_of_interest  shopping_mall   134  0.792899
# 151          clothing_store  shopping_mall    12  0.071006
# 768                   store  shopping_mall     7  0.041420
# 794             supermarket  shopping_mall     2  0.011834
# 175        department_store  shopping_mall     2  0.011834
# 657                 premise  shopping_mall     1  0.005917
# 328  grocery_or_supermarket  shopping_mall     1  0.005917
# 290         furniture_store  shopping_mall     1  0.005917
# 662      real_estate_agency  shopping_mall     1  0.005917
# 647             post_office  shopping_mall     1  0.005917
# 403        home_goods_store  shopping_mall     1  0.005917
# 544                 parking  shopping_mall     1  0.005917
# 435                  lawyer  shopping_mall     1  0.005917
# 554                pharmacy  shopping_mall     1  0.005917
# 450            liquor_store  shopping_mall     1  0.005917
# 58                      bar  shopping_mall     1  0.005917
# 294             gas_station  shopping_mall     1  0.005917
#
# CHILDREN
#             parent          category  freq      prop
# 716  shopping_mall              NULL   162  0.958580
# 717  shopping_mall    clothing_store     3  0.017751
# 721  shopping_mall             store     1  0.005917
# 720  shopping_mall        shoe_store     1  0.005917
# 719  shopping_mall   furniture_store     1  0.005917
# 718  shopping_mall  department_store     1  0.005917
#
#
# -----
# types: ['car_rental']
#
# >>> car_rental
# visited : {'freq': 141, 'prop': 0.003}
# all     : {'freq': 117, 'prop': 0.003}
# PARENT
#                 parent    category  freq      prop
# 603  point_of_interest  car_rental   102  0.871795
# 121         car_repair  car_rental     4  0.034188
# 801         taxi_stand  car_rental     2  0.017094
# 502     moving_company  car_rental     2  0.017094
# 108         car_dealer  car_rental     2  0.017094
# 260               food  car_rental     2  0.017094
# 136           car_wash  car_rental     1  0.008547
# 814      travel_agency  car_rental     1  0.008547
# 473            lodging  car_rental     1  0.008547
#
# CHILDREN
#          parent            category  freq      prop
# 112  car_rental                NULL   112  0.957265
# 113  car_rental       travel_agency     3  0.025641
# 115  car_rental  real_estate_agency     1  0.008547
# 114  car_rental          car_dealer     1  0.008547
#
#
# -----
# types: ['movie_theater']
#
# >>> movie_theater
# visited : {'freq': 75, 'prop': 0.002}
# all     : {'freq': 99, 'prop': 0.002}
# PARENT
#                 parent       category  freq      prop
# 604  point_of_interest  movie_theater    96  0.969697
# 832         university  movie_theater     1  0.010101
# 688         restaurant  movie_theater     1  0.010101
# 402   home_goods_store  movie_theater     1  0.010101
#
# CHILDREN
#             parent           category  freq      prop
# 498  movie_theater               NULL    96  0.969697
# 499  movie_theater                bar     2  0.020202
# 500  movie_theater  electronics_store     1  0.010101
#
#
# -----
# types: ['funeral_home']
#
# >>> funeral_home
# visited : {'freq': 20, 'prop': 0.0}
# all     : {'freq': 62, 'prop': 0.001}
# PARENT
#                 parent      category  freq      prop
# 610  point_of_interest  funeral_home    58  0.935484
# 141             church  funeral_home     1  0.016129
# 778              store  funeral_home     1  0.016129
# 413   insurance_agency  funeral_home     1  0.016129
# 525            painter  funeral_home     1  0.016129
#
# CHILDREN
#            parent category  freq      prop
# 271  funeral_home     NULL    61  0.983871
# 272  funeral_home  florist     1  0.016129
#
#
# -----
# types: ['cemetery']
#
# >>> cemetery
# visited : {'freq': 85, 'prop': 0.002}
# all     : {'freq': 55, 'prop': 0.001}
# PARENT
#                 parent  category  freq      prop
# 615  point_of_interest  cemetery    41  0.745455
# 650            premise  cemetery    12  0.218182
# 534               park  cemetery     1  0.018182
# 228            finance  cemetery     1  0.018182
#
# CHILDREN
#        parent category  freq  prop
# 138  cemetery     NULL    55   1.0
#
#
# -----
# types: ['police']
#
# >>> police
# visited : {'freq': 62, 'prop': 0.001}
# all     : {'freq': 52, 'prop': 0.001}
# PARENT
#                 parent category  freq      prop
# 613  point_of_interest   police    51  0.980769
# 234       fire_station   police     1  0.019231
#
# CHILDREN
#      parent category  freq      prop
# 639  police     NULL    51  0.980769
# 640  police  premise     1  0.019231
#
#
# -----
# types: ['car_wash']
#
# >>> car_wash
# visited : {'freq': 82, 'prop': 0.002}
# all     : {'freq': 93, 'prop': 0.002}
# PARENT
#                 parent  category  freq      prop
# 614  point_of_interest  car_wash    45  0.483871
# 252               food  car_wash    18  0.193548
# 118         car_repair  car_wash    16  0.172043
# 88                cafe  car_wash    10  0.107527
# 32              bakery  car_wash     2  0.021505
# 533               park  car_wash     1  0.010753
# 398   home_goods_store  car_wash     1  0.010753
#
# CHILDREN
#        parent                category  freq      prop
# 131  car_wash                    NULL    41  0.440860
# 132  car_wash       convenience_store    25  0.268817
# 133  car_wash             gas_station    13  0.139785
# 134  car_wash              car_dealer     8  0.086022
# 135  car_wash  grocery_or_supermarket     5  0.053763
# 136  car_wash              car_rental     1  0.010753
#
#
# -----
# types: ['moving_company']
#
# >>> moving_company
# visited : {'freq': 126, 'prop': 0.003}
# all     : {'freq': 91, 'prop': 0.002}
# PARENT
#                  parent        category  freq      prop
# 731             storage  moving_company    59  0.648352
# 619   point_of_interest  moving_company    21  0.230769
# 424             laundry  moving_company     3  0.032967
# 308  general_contractor  moving_company     2  0.021978
# 395    home_goods_store  moving_company     2  0.021978
# 128          car_repair  moving_company     1  0.010989
# 782               store  moving_company     1  0.010989
# 232             finance  moving_company     1  0.010989
# 288     furniture_store  moving_company     1  0.010989
#
# CHILDREN
#              parent           category  freq      prop
# 501  moving_company               NULL    87  0.956044
# 502  moving_company         car_rental     2  0.021978
# 504  moving_company  electronics_store     1  0.010989
# 503  moving_company               bank     1  0.010989
#
#
# -----
# types: ['roofing_contractor']
#
# >>> roofing_contractor
# visited : {'freq': 14, 'prop': 0.0}
# all     : {'freq': 38, 'prop': 0.001}
# PARENT
#                  parent            category  freq      prop
# 621   point_of_interest  roofing_contractor    16  0.421053
# 383    home_goods_store  roofing_contractor    12  0.315789
# 302  general_contractor  roofing_contractor     5  0.131579
# 772               store  roofing_contractor     3  0.078947
# 130          car_repair  roofing_contractor     1  0.026316
# 526             painter  roofing_contractor     1  0.026316
#
# CHILDREN
#                  parent        category  freq      prop
# 692  roofing_contractor            NULL    29  0.763158
# 693  roofing_contractor         plumber     7  0.184211
# 694  roofing_contractor  hardware_store     2  0.052632
#
#
# -----
# types: ['amusement_park']
#
# >>> amusement_park
# visited : {'freq': 86, 'prop': 0.002}
# all     : {'freq': 20, 'prop': 0.0}
# PARENT
#                 parent        category  freq  prop
# 620  point_of_interest  amusement_park    16  0.80
# 531               park  amusement_park     2  0.10
# 471            lodging  amusement_park     1  0.05
# 331                gym  amusement_park     1  0.05
#
# CHILDREN
#             parent    category  freq  prop
# 10  amusement_park        NULL    16  0.80
# 11  amusement_park  campground     2  0.10
# 13  amusement_park         zoo     1  0.05
# 12  amusement_park      museum     1  0.05
#
#
# -----
# types: ['stadium']
#
# >>> stadium
# visited : {'freq': 636, 'prop': 0.013}
# all     : {'freq': 13, 'prop': 0.0}
# PARENT
#                 parent category  freq      prop
# 625  point_of_interest  stadium     8  0.615385
# 651            premise  stadium     5  0.384615
#
# CHILDREN
#       parent category  freq  prop
# 730  stadium     NULL    13   1.0
#
#
# -----
# types: ['airport']
#
# >>> airport
# visited : {'freq': 8, 'prop': 0.0}
# all     : {'freq': 13, 'prop': 0.0}
# PARENT
#                 parent category  freq      prop
# 624  point_of_interest  airport     9  0.692308
# 729                spa  airport     1  0.076923
# 812      travel_agency  airport     1  0.076923
# 825         university  airport     1  0.076923
# 53                 bar  airport     1  0.076923
#
# CHILDREN
#     parent    category  freq      prop
# 8  airport        NULL    12  0.923077
# 9  airport  night_club     1  0.076923
#
#
# -----
# types: ['courthouse']
#
# >>> courthouse
# visited : {'freq': 2, 'prop': 0.0}
# all     : {'freq': 7, 'prop': 0.0}
# PARENT
#                 parent    category  freq  prop
# 626  point_of_interest  courthouse     7   1.0
#
# CHILDREN
#          parent category  freq  prop
# 168  courthouse     NULL     7   1.0
#
#
# -----
# types: ['car_rental', 'moving_company']
#
# >>> car_rental
# visited : {'freq': 141, 'prop': 0.003}
# all     : {'freq': 117, 'prop': 0.003}
# PARENT
#                 parent    category  freq      prop
# 603  point_of_interest  car_rental   102  0.871795
# 121         car_repair  car_rental     4  0.034188
# 801         taxi_stand  car_rental     2  0.017094
# 502     moving_company  car_rental     2  0.017094
# 108         car_dealer  car_rental     2  0.017094
# 260               food  car_rental     2  0.017094
# 136           car_wash  car_rental     1  0.008547
# 814      travel_agency  car_rental     1  0.008547
# 473            lodging  car_rental     1  0.008547
#
# CHILDREN
#          parent            category  freq      prop
# 112  car_rental                NULL   112  0.957265
# 113  car_rental       travel_agency     3  0.025641
# 115  car_rental  real_estate_agency     1  0.008547
# 114  car_rental          car_dealer     1  0.008547
#
# >>> moving_company
# visited : {'freq': 126, 'prop': 0.003}
# all     : {'freq': 91, 'prop': 0.002}
# PARENT
#                  parent        category  freq      prop
# 731             storage  moving_company    59  0.648352
# 619   point_of_interest  moving_company    21  0.230769
# 424             laundry  moving_company     3  0.032967
# 308  general_contractor  moving_company     2  0.021978
# 395    home_goods_store  moving_company     2  0.021978
# 128          car_repair  moving_company     1  0.010989
# 782               store  moving_company     1  0.010989
# 232             finance  moving_company     1  0.010989
# 288     furniture_store  moving_company     1  0.010989
#
# CHILDREN
#              parent           category  freq      prop
# 501  moving_company               NULL    87  0.956044
# 502  moving_company         car_rental     2  0.021978
# 504  moving_company  electronics_store     1  0.010989
# 503  moving_company               bank     1  0.010989
#
#
# -----
# types: ['movie_rental']
#
# >>> movie_rental
# visited : {'freq': 9, 'prop': 0.0}
# all     : {'freq': 38, 'prop': 0.001}
# PARENT
#                 parent      category  freq      prop
# 198  electronics_store  movie_rental    30  0.789474
# 774              store  movie_rental     2  0.052632
# 75          book_store  movie_rental     2  0.052632
# 161     clothing_store  movie_rental     1  0.026316
# 553           pharmacy  movie_rental     1  0.026316
# 401   home_goods_store  movie_rental     1  0.026316
# 635  point_of_interest  movie_rental     1  0.026316
#
# CHILDREN
#            parent           category  freq      prop
# 494  movie_rental               NULL    28  0.736842
# 495  movie_rental         book_store     8  0.210526
# 496  movie_rental  electronics_store     1  0.026316
# 497  movie_rental              store     1  0.026316
#
#
# -----
# types: ['aquarium']
#
# >>> aquarium
# visited : {'freq': 0, 'prop': 0.0}
# all     : {'freq': 1, 'prop': 0.0}
# PARENT
#                 parent  category  freq  prop
# 632  point_of_interest  aquarium     1   1.0
#
# CHILDREN
#       parent category  freq  prop
# 14  aquarium     NULL     1   1.0
#
#
# -----
# types: ['route']
#
# >>> route
# visited : {'freq': 0, 'prop': 0.0}
# all     : {'freq': 1, 'prop': 0.0}
# PARENT
#                 parent category  freq  prop
# 638  point_of_interest    route     1   1.0
#
# CHILDREN
#     parent category  freq  prop
# 695  route     NULL     1   1.0

# %% [markdown]
# #  Mapping User 6189

# %% [markdown]
# Ver os casos de <b>store</b>

# %%
tags_sequence = users_tags_sequence["6189"]
categ_sequence = []

for tags in tags_sequence:
    if tags == ["WORK"] or tags == ["HOME"]:
        categ_sequence.append(tags)

    else:
        try:
            categ = categ_mapper.map_categ(tags, logs=True)
            categ_sequence.append([categ])

        except NoCategoryMatched:
            categ_sequence.append("NoCategoryMatched") 

for i in range(len(categ_sequence)):
    print(categ_sequence[i], "<<<", users_tags_sequence["6189"][i])
# Out:
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['finance', 'finance', 'health', 'general_contractor']
#
# MAPPED: ['finance', 'finance', 'health', 'general_contractor']
# most_frequent: ['finance']
# most_specific: finance
# chosen method: most_specific
#
# ---
# TYPES : ['insurance_agency', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['insurance_agency']
#
# MAPPED: ['health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['bakery', 'cafe', 'restaurant', 'food', 'store', 'restaurant', 'food']
#
# MAPPED: ['bakery', 'cafe', 'restaurant', 'store', 'store', 'restaurant', 'store']
# most_frequent: ['store']
# most_specific: bakery
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['health', 'hospital']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['doctor', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'physiotherapist', 'health', 'physiotherapist', 'health']
#
# MAPPED: ['health', 'health', 'health', 'health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['real_estate_agency']
#
# MAPPED: ['real_estate_agency']
# most_frequent: ['real_estate_agency']
# most_specific: real_estate_agency
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['finance']
#
# MAPPED: ['finance']
# most_frequent: ['finance']
# most_specific: finance
# chosen method: most_specific
#
# ---
# TYPES : ['meal_takeaway', 'restaurant', 'food']
#
# MAPPED: ['restaurant', 'restaurant', 'store']
# most_frequent: ['restaurant']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['health', 'hospital']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['parking']
#
# MAPPED: ['bar']
# most_frequent: ['bar']
# most_specific: bar
# chosen method: most_specific
#
# ---
# TYPES : ['hospital', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['grocery_or_supermarket', 'food', 'store']
#
# MAPPED: ['grocery_or_supermarket', 'store', 'store']
# most_frequent: ['store']
# most_specific: grocery_or_supermarket
# chosen method: most_specific
#
# ---
# TYPES : ['food']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
#
# MAPPED: ['convenience_store', 'convenience_store', 'cafe', 'store', 'store']
# most_frequent: ['convenience_store', 'store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['health', 'hospital']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['meal_takeaway', 'restaurant', 'food']
#
# MAPPED: ['restaurant', 'restaurant', 'store']
# most_frequent: ['restaurant']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['electrician']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['physiotherapist', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['electrician']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
#
# MAPPED: ['convenience_store', 'convenience_store', 'cafe', 'store', 'store']
# most_frequent: ['convenience_store', 'store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['moving_company', 'storage']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'dentist', 'health']
#
# MAPPED: ['health', 'health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['beauty_salon']
#
# MAPPED: ['beauty_salon']
# most_frequent: ['beauty_salon']
# most_specific: beauty_salon
# chosen method: most_specific
#
# ---
# TYPES : ['physiotherapist', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
# ---
# TYPES : ['travel_agency']
#
# MAPPED: ['travel_agency']
# most_frequent: ['travel_agency']
# most_specific: travel_agency
# chosen method: most_specific
#
# ---
# TYPES : ['meal_delivery', 'meal_takeaway', 'restaurant', 'food']
#
# MAPPED: ['restaurant', 'restaurant', 'store']
# most_frequent: ['restaurant']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['general_contractor']
#
# MAPPED: ['general_contractor']
# most_frequent: ['general_contractor']
# most_specific: general_contractor
# chosen method: most_specific
#
# ---
# TYPES : ['locksmith']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['real_estate_agency']
#
# MAPPED: ['real_estate_agency']
# most_frequent: ['real_estate_agency']
# most_specific: real_estate_agency
# chosen method: most_specific
#
# ---
# TYPES : ['church', 'place_of_worship']
#
# MAPPED: ['place_of_worship', 'place_of_worship']
# most_frequent: ['place_of_worship']
# most_specific: place_of_worship
# chosen method: most_specific
#
# ---
# TYPES : ['electrician']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['furniture_store', 'home_goods_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['locksmith']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['locksmith']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['pharmacy', 'health', 'store']
#
# MAPPED: ['health', 'health', 'store']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['locksmith']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['general_contractor']
#
# MAPPED: ['general_contractor']
# most_frequent: ['general_contractor']
# most_specific: general_contractor
# chosen method: most_specific
#
# ---
# TYPES : ['painter']
#
# MAPPED: ['general_contractor']
# most_frequent: ['general_contractor']
# most_specific: general_contractor
# chosen method: most_specific
#
# ---
# TYPES : ['pharmacy', 'health', 'store']
#
# MAPPED: ['health', 'health', 'store']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['electrician']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['veterinary_care', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['campground', 'park', 'lodging']
#
# MAPPED: ['lodging']
# most_frequent: ['lodging']
# most_specific: lodging
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['lodging']
#
# MAPPED: ['lodging']
# most_frequent: ['lodging']
# most_specific: lodging
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['spa', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['night_club', 'shoe_store', 'store', 'restaurant', 'food', 'night_club']
#
# MAPPED: ['bar', 'store', 'store', 'restaurant', 'store', 'bar']
# most_frequent: ['store']
# most_specific: bar
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['doctor', 'health', 'restaurant', 'food', 'restaurant', 'food']
#
# MAPPED: ['health', 'health', 'restaurant', 'store', 'restaurant', 'store']
# most_frequent: ['health', 'restaurant', 'store']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['supermarket', 'grocery_or_supermarket', 'food', 'store']
#
# MAPPED: ['supermarket', 'grocery_or_supermarket', 'store', 'store']
# most_frequent: ['store']
# most_specific: supermarket
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['electrician']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['fire_station']
#
# MAPPED: ['health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['general_contractor']
#
# MAPPED: ['general_contractor']
# most_frequent: ['general_contractor']
# most_specific: general_contractor
# chosen method: most_specific
#
# ---
# TYPES : ['fire_station']
#
# MAPPED: ['health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['general_contractor']
#
# MAPPED: ['general_contractor']
# most_frequent: ['general_contractor']
# most_specific: general_contractor
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
#
# MAPPED: ['convenience_store', 'convenience_store', 'cafe', 'store', 'store']
# most_frequent: ['convenience_store', 'store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['school']
#
# MAPPED: ['school']
# most_frequent: ['school']
# most_specific: school
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'dentist', 'health']
#
# MAPPED: ['health', 'health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'bar', 'food']
#
# MAPPED: ['restaurant', 'bar', 'store']
# most_frequent: ['restaurant', 'bar', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['real_estate_agency']
#
# MAPPED: ['real_estate_agency']
# most_frequent: ['real_estate_agency']
# most_specific: real_estate_agency
# chosen method: most_specific
#
# ---
# TYPES : ['doctor', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['finance', 'night_club', 'bar']
#
# MAPPED: ['finance', 'bar', 'bar']
# most_frequent: ['bar']
# most_specific: finance
# chosen method: most_specific
#
# ---
# TYPES : ['doctor', 'health', 'spa', 'health', 'store']
#
# MAPPED: ['health', 'health', 'health', 'health', 'store']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['real_estate_agency', 'dentist', 'doctor', 'health', 'furniture_store', 'home_goods_store', 'store']
#
# MAPPED: ['real_estate_agency', 'health', 'health', 'health', 'store', 'store']
# most_frequent: ['health']
# most_specific: real_estate_agency
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
#
# MAPPED: ['convenience_store', 'convenience_store', 'cafe', 'store', 'store']
# most_frequent: ['convenience_store', 'store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['health']
#
# MAPPED: ['health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['gym', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['finance']
#
# MAPPED: ['finance']
# most_frequent: ['finance']
# most_specific: finance
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['store']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
#
# MAPPED: ['convenience_store', 'convenience_store', 'cafe', 'store', 'store']
# most_frequent: ['convenience_store', 'store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['real_estate_agency']
#
# MAPPED: ['real_estate_agency']
# most_frequent: ['real_estate_agency']
# most_specific: real_estate_agency
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station']
#
# MAPPED: ['convenience_store']
# most_frequent: ['convenience_store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['general_contractor']
#
# MAPPED: ['general_contractor']
# most_frequent: ['general_contractor']
# most_specific: general_contractor
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station']
#
# MAPPED: ['convenience_store']
# most_frequent: ['convenience_store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['store', 'general_contractor']
#
# MAPPED: ['store', 'general_contractor']
# most_frequent: ['store', 'general_contractor']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station']
#
# MAPPED: ['convenience_store']
# most_frequent: ['convenience_store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair', 'car_repair']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['store']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['art_gallery']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['laundry']
#
# MAPPED: ['laundry']
# most_frequent: ['laundry']
# most_specific: laundry
# chosen method: most_specific
#
# ---
# TYPES : ['school']
#
# MAPPED: ['school']
# most_frequent: ['school']
# most_specific: school
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station']
#
# MAPPED: ['convenience_store']
# most_frequent: ['convenience_store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['parking']
#
# MAPPED: ['bar']
# most_frequent: ['bar']
# most_specific: bar
# chosen method: most_specific
#
# ---
# TYPES : ['physiotherapist', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['physiotherapist', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['physiotherapist', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station']
#
# MAPPED: ['convenience_store']
# most_frequent: ['convenience_store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['doctor', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['post_office', 'finance']
#
# MAPPED: ['finance', 'finance']
# most_frequent: ['finance']
# most_specific: finance
# chosen method: most_specific
#
# ---
# TYPES : ['food']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['physiotherapist', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['gym', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'convenience_store', 'food', 'store']
#
# MAPPED: ['convenience_store', 'convenience_store', 'store', 'store']
# most_frequent: ['convenience_store', 'store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['finance', 'real_estate_agency', 'finance']
#
# MAPPED: ['finance', 'real_estate_agency', 'finance']
# most_frequent: ['finance']
# most_specific: finance
# chosen method: most_specific
#
# ---
# TYPES : ['grocery_or_supermarket', 'food', 'store']
#
# MAPPED: ['grocery_or_supermarket', 'store', 'store']
# most_frequent: ['store']
# most_specific: grocery_or_supermarket
# chosen method: most_specific
#
# ---
# TYPES : ['health']
#
# MAPPED: ['health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
#
# MAPPED: ['convenience_store', 'convenience_store', 'cafe', 'store', 'store']
# most_frequent: ['convenience_store', 'store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food', 'physiotherapist', 'health', 'doctor', 'health', 'doctor', 'health', 'physiotherapist', 'health']
#
# MAPPED: ['restaurant', 'store', 'health', 'health', 'health', 'health', 'health', 'health', 'health', 'health']
# most_frequent: ['health']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['finance']
#
# MAPPED: ['finance']
# most_frequent: ['finance']
# most_specific: finance
# chosen method: most_specific
#
# ---
# TYPES : ['school']
#
# MAPPED: ['school']
# most_frequent: ['school']
# most_specific: school
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
#
# MAPPED: ['convenience_store', 'convenience_store', 'cafe', 'store', 'store']
# most_frequent: ['convenience_store', 'store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['home_goods_store', 'store', 'general_contractor', 'store']
#
# MAPPED: ['store', 'store', 'general_contractor', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['moving_company', 'storage']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['gym', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['finance']
#
# MAPPED: ['finance']
# most_frequent: ['finance']
# most_specific: finance
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['lodging']
#
# MAPPED: ['lodging']
# most_frequent: ['lodging']
# most_specific: lodging
# chosen method: most_specific
#
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['clothing_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'dentist', 'health']
#
# MAPPED: ['health', 'health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'dentist', 'health']
#
# MAPPED: ['health', 'health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['parking']
#
# MAPPED: ['bar']
# most_frequent: ['bar']
# most_specific: bar
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['meal_takeaway', 'restaurant', 'food']
#
# MAPPED: ['restaurant', 'restaurant', 'store']
# most_frequent: ['restaurant']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station']
#
# MAPPED: ['convenience_store']
# most_frequent: ['convenience_store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['beauty_salon']
#
# MAPPED: ['beauty_salon']
# most_frequent: ['beauty_salon']
# most_specific: beauty_salon
# chosen method: most_specific
#
# ---
# TYPES : ['general_contractor']
#
# MAPPED: ['general_contractor']
# most_frequent: ['general_contractor']
# most_specific: general_contractor
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'car_wash']
#
# MAPPED: ['convenience_store']
# most_frequent: ['convenience_store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['school']
#
# MAPPED: ['school']
# most_frequent: ['school']
# most_specific: school
# chosen method: most_specific
#
# ---
# TYPES : ['physiotherapist', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
#
# MAPPED: ['convenience_store', 'convenience_store', 'cafe', 'store', 'store']
# most_frequent: ['convenience_store', 'store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['real_estate_agency', 'dentist', 'doctor', 'health', 'furniture_store', 'home_goods_store', 'store']
#
# MAPPED: ['real_estate_agency', 'health', 'health', 'health', 'store', 'store']
# most_frequent: ['health']
# most_specific: real_estate_agency
# chosen method: most_specific
#
# ---
# TYPES : ['doctor', 'health', 'school']
#
# MAPPED: ['health', 'health', 'school']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['doctor', 'health']
#
# MAPPED: ['health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['pharmacy', 'health', 'store']
#
# MAPPED: ['health', 'health', 'store']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station']
#
# MAPPED: ['convenience_store']
# most_frequent: ['convenience_store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['furniture_store', 'laundry', 'home_goods_store', 'store', 'general_contractor']
#
# MAPPED: ['laundry', 'store', 'store', 'general_contractor']
# most_frequent: ['store']
# most_specific: laundry
# chosen method: most_specific
#
# ---
# TYPES : ['hardware_store', 'furniture_store', 'home_goods_store', 'store', 'atm', 'finance', 'clothing_store', 'bicycle_store', 'store', 'furniture_store', 'shopping_mall', 'home_goods_store', 'store', 'grocery_or_supermarket', 'supermarket', 'food', 'store', 'cafe', 'food', 'store', 'jewelry_store', 'store', 'restaurant', 'cafe', 'food', 'post_office', 'finance', 'store', 'movie_rental', 'electronics_store', 'home_goods_store', 'store']
#
# MAPPED: ['store', 'store', 'store', 'finance', 'finance', 'store', 'store', 'store', 'store', 'store', 'grocery_or_supermarket', 'supermarket', 'store', 'store', 'cafe', 'store', 'store', 'store', 'store', 'restaurant', 'cafe', 'store', 'finance', 'finance', 'store', 'store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['travel_agency']
#
# MAPPED: ['travel_agency']
# most_frequent: ['travel_agency']
# most_specific: travel_agency
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['car_dealer', 'car_repair', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['general_contractor']
#
# MAPPED: ['general_contractor']
# most_frequent: ['general_contractor']
# most_specific: general_contractor
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['store']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['shoe_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['bicycle_store', 'store']
#
# MAPPED: ['store', 'store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['general_contractor']
#
# MAPPED: ['general_contractor']
# most_frequent: ['general_contractor']
# most_specific: general_contractor
# chosen method: most_specific
#
# ---
# TYPES : ['store']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['beauty_salon']
#
# MAPPED: ['beauty_salon']
# most_frequent: ['beauty_salon']
# most_specific: beauty_salon
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['bowling_alley', 'bar', 'home_goods_store', 'store']
#
# MAPPED: ['restaurant', 'bar', 'store', 'store']
# most_frequent: ['store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['beauty_salon']
#
# MAPPED: ['beauty_salon']
# most_frequent: ['beauty_salon']
# most_specific: beauty_salon
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
#
# MAPPED: ['convenience_store', 'convenience_store', 'cafe', 'store', 'store']
# most_frequent: ['convenience_store', 'store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['gas_station']
#
# MAPPED: ['convenience_store']
# most_frequent: ['convenience_store']
# most_specific: convenience_store
# chosen method: most_specific
#
# ---
# TYPES : ['real_estate_agency', 'dentist', 'doctor', 'health', 'furniture_store', 'home_goods_store', 'store']
#
# MAPPED: ['real_estate_agency', 'health', 'health', 'health', 'store', 'store']
# most_frequent: ['health']
# most_specific: real_estate_agency
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['store']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['restaurant', 'food']
#
# MAPPED: ['restaurant', 'store']
# most_frequent: ['restaurant', 'store']
# most_specific: restaurant
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['liquor_store', 'convenience_store', 'restaurant', 'food', 'store']
#
# MAPPED: ['liquor_store', 'convenience_store', 'restaurant', 'store', 'store']
# most_frequent: ['store']
# most_specific: liquor_store
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['bakery', 'food', 'store']
#
# MAPPED: ['bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: bakery
# chosen method: most_specific
#
# ---
# TYPES : ['school']
#
# MAPPED: ['school']
# most_frequent: ['school']
# most_specific: school
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['bus_station', 'transit_station']
#
# MAPPED: ['transit_station', 'transit_station']
# most_frequent: ['transit_station']
# most_specific: transit_station
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['dentist', 'health', 'health']
#
# MAPPED: ['health', 'health', 'health']
# most_frequent: ['health']
# most_specific: health
# chosen method: most_specific
#
# ---
# TYPES : ['post_office', 'finance']
#
# MAPPED: ['finance', 'finance']
# most_frequent: ['finance']
# most_specific: finance
# chosen method: most_specific
#
# ---
# TYPES : ['real_estate_agency', 'dentist', 'doctor', 'health', 'furniture_store', 'home_goods_store', 'store']
#
# MAPPED: ['real_estate_agency', 'health', 'health', 'health', 'store', 'store']
# most_frequent: ['health']
# most_specific: real_estate_agency
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['bank', 'finance']
#
# MAPPED: ['finance', 'finance']
# most_frequent: ['finance']
# most_specific: finance
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['school']
#
# MAPPED: ['school']
# most_frequent: ['school']
# most_specific: school
# chosen method: most_specific
#
# ---
# TYPES : ['hair_care']
#
# MAPPED: ['hair_care']
# most_frequent: ['hair_care']
# most_specific: hair_care
# chosen method: most_specific
#
# ---
# TYPES : ['lodging']
#
# MAPPED: ['lodging']
# most_frequent: ['lodging']
# most_specific: lodging
# chosen method: most_specific
#
# ---
# TYPES : ['locality', 'political']
#
# MAPPED: ['political', 'political']
# most_frequent: ['political']
# most_specific: political
# chosen method: most_specific
#
# ---
# TYPES : ['campground', 'park', 'lodging']
#
# MAPPED: ['lodging']
# most_frequent: ['lodging']
# most_specific: lodging
# chosen method: most_specific
#
# ---
# TYPES : ['car_repair']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
#
# ---
# TYPES : ['beauty_salon']
#
# MAPPED: ['beauty_salon']
# most_frequent: ['beauty_salon']
# most_specific: beauty_salon
# chosen method: most_specific
#
# ---
# TYPES : ['moving_company', 'storage']
#
# MAPPED: ['store']
# most_frequent: ['store']
# most_specific: store
# chosen method: most_specific
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['HOME'] <<< ['HOME']
# ['health'] <<< ['dentist', 'health', 'health']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['finance'] <<< ['finance', 'finance', 'health', 'general_contractor']
# ['health'] <<< ['insurance_agency', 'health']
# ['health'] <<< ['insurance_agency']
# NoCategoryMatched <<< ['park', 'premise']
# ...
# ['WORK'] <<< ['WORK']
# ['political'] <<< ['locality', 'political']
# ['finance'] <<< ['finance']
# NoCategoryMatched <<< ['park', 'premise']
# ['restaurant'] <<< ['meal_takeaway', 'restaurant', 'food']
# ['restaurant'] <<< ['restaurant', 'food']
# ['health'] <<< ['health', 'hospital']
# ['bar'] <<< ['parking']
# ['HOME'] <<< ['HOME']
# ['health'] <<< ['hospital', 'health']
# ['store'] <<< ['car_repair']
# ['grocery_or_supermarket'] <<< ['grocery_or_supermarket', 'food', 'store']
# ['HOME'] <<< ['HOME']
# ['store'] <<< ['food']
# ['HOME'] <<< ['HOME']
# ['political'] <<< ['locality', 'political']
# ['convenience_store'] <<< ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['health'] <<< ['health', 'hospital']
# ['WORK'] <<< ['WORK']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['HOME'] <<< ['HOME']
# ['store'] <<< ['car_repair']
# ['store'] <<< ['clothing_store', 'store']
# ['store'] <<< ['car_repair']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['WORK'] <<< ['WORK']
# ['WORK'] <<< ['WORK']
# ['restaurant'] <<< ['meal_takeaway', 'restaurant', 'food']
# ['store'] <<< ['electrician']
# ['health'] <<< ['physiotherapist', 'health']
# ['store'] <<< ['electrician']
# ['convenience_store'] <<< ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['HOME'] <<< ['HOME']
# ['political'] <<< ['locality', 'political']
# ['store'] <<< ['moving_company', 'storage']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['WORK'] <<< ['WORK']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['store'] <<< ['car_repair']
# ['store'] <<< ['clothing_store', 'store']
# ['health'] <<< ['dentist', 'health', 'dentist', 'health']
# ['health'] <<< ['dentist', 'health', 'health']
# ['beauty_salon'] <<< ['beauty_salon']
# ['WORK'] <<< ['WORK']
# ['health'] <<< ['physiotherapist', 'health']
# ['restaurant'] <<< ['restaurant', 'food']
# ['WORK'] <<< ['WORK']
# ['HOME'] <<< ['HOME']
# ['WORK'] <<< ['WORK']
# ['political'] <<< ['locality', 'political']
# ['restaurant'] <<< ['restaurant', 'food']
# ['political'] <<< ['locality', 'political']
# ['travel_agency'] <<< ['travel_agency']
# ['restaurant'] <<< ['meal_delivery', 'meal_takeaway', 'restaurant', 'food']
# ['general_contractor'] <<< ['general_contractor']
# ['store'] <<< ['locksmith']
# ['HOME'] <<< ['HOME']
# ['real_estate_agency'] <<< ['real_estate_agency']
# ['place_of_worship'] <<< ['church', 'place_of_worship']
# ['store'] <<< ['electrician']
# ['store'] <<< ['clothing_store', 'store']
# ['store'] <<< ['furniture_store', 'home_goods_store', 'store']
# ['health'] <<< ['dentist', 'health', 'health']
# ['restaurant'] <<< ['restaurant', 'food']
# ['HOME'] <<< ['HOME']
# ['health'] <<< ['dentist', 'health', 'health']
# ['store'] <<< ['car_repair']
# ['store'] <<< ['locksmith']
# ['store'] <<< ['clothing_store', 'store']
# ['store'] <<< ['locksmith']
# ['store'] <<< ['car_repair']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# NoCategoryMatched <<< ['police']
# ['health'] <<< ['pharmacy', 'health', 'store']
# ['health'] <<< ['dentist', 'health']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['HOME'] <<< ['HOME']
# ['store'] <<< ['locksmith']
# ['store'] <<< ['car_repair']
# ['store'] <<< ['car_repair']
# ['WORK'] <<< ['WORK']
# ['HOME'] <<< ['HOME']
# ['restaurant'] <<< ['restaurant', 'food']
# ['general_contractor'] <<< ['general_contractor']
# ['HOME'] <<< ['HOME']
# ['general_contractor'] <<< ['painter']
# ['health'] <<< ['pharmacy', 'health', 'store']
# ['HOME'] <<< ['HOME']
# ['hair_care'] <<< ['hair_care']
# ['political'] <<< ['locality', 'political']
# NoCategoryMatched <<< ['police']
# ['store'] <<< ['electrician']
# NoCategoryMatched <<< ['cemetery', 'premise']
# ['HOME'] <<< ['HOME']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['store'] <<< ['clothing_store', 'store']
# ['HOME'] <<< ['HOME']
# ['WORK'] <<< ['WORK']
# ['store'] <<< ['car_repair']
# ['health'] <<< ['veterinary_care', 'health']
# ['WORK'] <<< ['WORK']
# ['HOME'] <<< ['HOME']
# ['political'] <<< ['locality', 'political']
# ['political'] <<< ['locality', 'political']
# ['HOME'] <<< ['HOME']
# ['lodging'] <<< ['campground', 'park', 'lodging']
# ['WORK'] <<< ['WORK']
# ['restaurant'] <<< ['restaurant', 'food']
# ['HOME'] <<< ['HOME']
# ['lodging'] <<< ['lodging']
# ['WORK'] <<< ['WORK']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['health'] <<< ['spa', 'health']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['HOME'] <<< ['HOME']
# ['bar'] <<< ['night_club', 'shoe_store', 'store', 'restaurant', 'food', 'night_club']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['health'] <<< ['doctor', 'health', 'restaurant', 'food', 'restaurant', 'food']
# ['supermarket'] <<< ['supermarket', 'grocery_or_supermarket', 'food', 'store']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['store'] <<< ['car_repair']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['store'] <<< ['electrician']
# ['health'] <<< ['fire_station']
# ['general_contractor'] <<< ['general_contractor']
# ['health'] <<< ['fire_station']
# ['general_contractor'] <<< ['general_contractor']
# ['HOME'] <<< ['HOME']
# ['WORK'] <<< ['WORK']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['convenience_store'] <<< ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
# ['political'] <<< ['locality', 'political']
# ['health'] <<< ['dentist', 'health', 'health']
# ['WORK'] <<< ['WORK']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['HOME'] <<< ['HOME']
# ['school'] <<< ['school']
# ['HOME'] <<< ['HOME']
# ['health'] <<< ['dentist', 'health', 'dentist', 'health']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['restaurant'] <<< ['restaurant', 'food']
# ['HOME'] <<< ['HOME']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['store'] <<< ['clothing_store', 'store']
# ['store'] <<< ['car_repair']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['restaurant'] <<< ['restaurant', 'bar', 'food']
# ['real_estate_agency'] <<< ['real_estate_agency']
# ['health'] <<< ['doctor', 'health']
# ['WORK'] <<< ['WORK']
# ['health'] <<< ['dentist', 'health', 'health']
# ['WORK'] <<< ['WORK']
# ['finance'] <<< ['finance', 'night_club', 'bar']
# ['health'] <<< ['doctor', 'health', 'spa', 'health', 'store']
# NoCategoryMatched <<< ['shopping_mall']
# ['restaurant'] <<< ['restaurant', 'food']
# ['HOME'] <<< ['HOME']
# ['WORK'] <<< ['WORK']
# ['political'] <<< ['locality', 'political']
# ['real_estate_agency'] <<< ['real_estate_agency', 'dentist', 'doctor', 'health', 'furniture_store', 'home_goods_store', 'store']
# ['convenience_store'] <<< ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
# ['hair_care'] <<< ['hair_care']
# ['WORK'] <<< ['WORK']
# ['health'] <<< ['health']
# ['WORK'] <<< ['WORK']
# ['HOME'] <<< ['HOME']
# ['health'] <<< ['gym', 'health']
# ['WORK'] <<< ['WORK']
# ['finance'] <<< ['finance']
# ['WORK'] <<< ['WORK']
# ['restaurant'] <<< ['restaurant', 'food']
# ['restaurant'] <<< ['restaurant', 'food']
# ['store'] <<< ['store']
# ['HOME'] <<< ['HOME']
# ['convenience_store'] <<< ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
# ['real_estate_agency'] <<< ['real_estate_agency']
# ['political'] <<< ['locality', 'political']
# ['convenience_store'] <<< ['gas_station']
# ['general_contractor'] <<< ['general_contractor']
# NoCategoryMatched <<< ['park']
# ['convenience_store'] <<< ['gas_station']
# ['restaurant'] <<< ['restaurant', 'food']
# ['store'] <<< ['clothing_store', 'store']
# ['HOME'] <<< ['HOME']
# ['political'] <<< ['locality', 'political']
# ['HOME'] <<< ['HOME']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['store'] <<< ['store', 'general_contractor']
# ['health'] <<< ['dentist', 'health', 'health']
# ['convenience_store'] <<< ['gas_station']
# ['store'] <<< ['car_repair', 'car_repair']
# ['HOME'] <<< ['HOME']
# ['WORK'] <<< ['WORK']
# NoCategoryMatched <<< ['police']
# ['store'] <<< ['store']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['store'] <<< ['art_gallery']
# ['health'] <<< ['dentist', 'health', 'health']
# ['laundry'] <<< ['laundry']
# ['school'] <<< ['school']
# ['HOME'] <<< ['HOME']
# ['convenience_store'] <<< ['gas_station']
# ['bar'] <<< ['premise', 'parking']
# ['WORK'] <<< ['WORK']
# ['health'] <<< ['physiotherapist', 'health']
# ['health'] <<< ['dentist', 'health', 'health']
# ['health'] <<< ['physiotherapist', 'health']
# ['health'] <<< ['physiotherapist', 'health']
# ['WORK'] <<< ['WORK']
# ['store'] <<< ['clothing_store', 'store']
# ['HOME'] <<< ['HOME']
# ['restaurant'] <<< ['restaurant', 'food']
# ['convenience_store'] <<< ['gas_station']
# ['store'] <<< ['clothing_store', 'store']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['health'] <<< ['doctor', 'health']
# ['WORK'] <<< ['WORK']
# ['restaurant'] <<< ['restaurant', 'food']
# ['HOME'] <<< ['HOME']
# ['health'] <<< ['dentist', 'health', 'health']
# ['HOME'] <<< ['HOME']
# ['health'] <<< ['dentist', 'health', 'health']
# ['HOME'] <<< ['HOME']
# ['political'] <<< ['locality', 'political']
# ['HOME'] <<< ['HOME']
# ['WORK'] <<< ['WORK']
# ['finance'] <<< ['post_office', 'finance']
# ['HOME'] <<< ['HOME']
# ['WORK'] <<< ['WORK']
# ['store'] <<< ['food']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# NoCategoryMatched <<< ['cemetery', 'premise']
# ['health'] <<< ['physiotherapist', 'health']
# ['HOME'] <<< ['HOME']
# ['health'] <<< ['gym', 'health']
# ['HOME'] <<< ['HOME']
# ['health'] <<< ['dentist', 'health', 'health']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['hair_care'] <<< ['hair_care']
# ['convenience_store'] <<< ['gas_station', 'convenience_store', 'food', 'store']
# ['finance'] <<< ['finance', 'real_estate_agency', 'finance']
# ['grocery_or_supermarket'] <<< ['grocery_or_supermarket', 'food', 'store']
# ['health'] <<< ['health']
# ['political'] <<< ['locality', 'political']
# ['WORK'] <<< ['WORK']
# ['convenience_store'] <<< ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
# ['HOME'] <<< ['HOME']
# ['political'] <<< ['locality', 'political']
# ['WORK'] <<< ['WORK']
# ['restaurant'] <<< ['restaurant', 'food', 'physiotherapist', 'health', 'doctor', 'health', 'doctor', 'health', 'physiotherapist', 'health']
# ['finance'] <<< ['finance']
# ['school'] <<< ['school']
# ['convenience_store'] <<< ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
# ['HOME'] <<< ['HOME']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['store'] <<< ['home_goods_store', 'store', 'general_contractor', 'store']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['HOME'] <<< ['HOME']
# ['WORK'] <<< ['WORK']
# ['store'] <<< ['moving_company', 'storage']
# ['health'] <<< ['gym', 'health']
# ['finance'] <<< ['finance']
# ['political'] <<< ['locality', 'political']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['WORK'] <<< ['WORK']
# ['lodging'] <<< ['lodging']
# ['cafe'] <<< ['cafe', 'food', 'bakery', 'food', 'store']
# ['store'] <<< ['clothing_store', 'store']
# ['hair_care'] <<< ['hair_care']
# ['store'] <<< ['clothing_store', 'store']
# ['health'] <<< ['dentist', 'health', 'dentist', 'health']
# ['restaurant'] <<< ['restaurant', 'food']
# ['health'] <<< ['dentist', 'health', 'dentist', 'health']
# ['HOME'] <<< ['HOME']
# ['store'] <<< ['car_repair']
# ['HOME'] <<< ['HOME']
# ['WORK'] <<< ['WORK']
# ['bar'] <<< ['parking']
# ['WORK'] <<< ['WORK']
# ['restaurant'] <<< ['restaurant', 'food']
# ['restaurant'] <<< ['meal_takeaway', 'restaurant', 'food']
# ['HOME'] <<< ['HOME']
# ['convenience_store'] <<< ['gas_station']
# ['WORK'] <<< ['WORK']
# ['health'] <<< ['dentist', 'health', 'health']
# ['beauty_salon'] <<< ['beauty_salon']
# ['HOME'] <<< ['HOME']
# ['general_contractor'] <<< ['general_contractor']
# ['convenience_store'] <<< ['gas_station', 'car_wash']
# ['HOME'] <<< ['HOME']
# ['hair_care'] <<< ['hair_care']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['HOME'] <<< ['HOME']
# ['school'] <<< ['school']
# ['health'] <<< ['physiotherapist', 'health']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['convenience_store'] <<< ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
# ['real_estate_agency'] <<< ['real_estate_agency', 'dentist', 'doctor', 'health', 'furniture_store', 'home_goods_store', 'store']
# ['health'] <<< ['doctor', 'health', 'school']
# ['health'] <<< ['doctor', 'health']
# ['health'] <<< ['pharmacy', 'health', 'store']
# ['political'] <<< ['locality', 'political']
# ['convenience_store'] <<< ['gas_station']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['laundry'] <<< ['furniture_store', 'laundry', 'home_goods_store', 'store', 'general_contractor']
# ['store'] <<< ['hardware_store', 'furniture_store', 'home_goods_store', 'store', 'atm', 'finance', 'clothing_store', 'bicycle_store', 'store', 'furniture_store', 'shopping_mall', 'home_goods_store', 'store', 'grocery_or_supermarket', 'supermarket', 'food', 'store', 'cafe', 'food', 'store', 'jewelry_store', 'store', 'restaurant', 'cafe', 'food', 'post_office', 'finance', 'store', 'movie_rental', 'electronics_store', 'home_goods_store', 'store']
# ['HOME'] <<< ['HOME']
# ['political'] <<< ['locality', 'political']
# ['store'] <<< ['car_repair']
# ['travel_agency'] <<< ['travel_agency']
# ['political'] <<< ['locality', 'political']
# NoCategoryMatched <<< ['police']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['HOME'] <<< ['HOME']
# ['store'] <<< ['car_dealer', 'car_repair', 'store']
# ['WORK'] <<< ['WORK']
# ['HOME'] <<< ['HOME']
# ['political'] <<< ['locality', 'political']
# ['health'] <<< ['dentist', 'health', 'health']
# ['general_contractor'] <<< ['general_contractor']
# ['political'] <<< ['locality', 'political']
# ['HOME'] <<< ['HOME']
# ['store'] <<< ['store']
# ['HOME'] <<< ['HOME']
# ['store'] <<< ['shoe_store', 'store']
# ['HOME'] <<< ['HOME']
# ['store'] <<< ['bicycle_store', 'store']
# ['restaurant'] <<< ['restaurant', 'food']
# ['general_contractor'] <<< ['general_contractor']
# ['store'] <<< ['store']
# ['HOME'] <<< ['HOME']
# ['beauty_salon'] <<< ['beauty_salon']
# ['WORK'] <<< ['WORK']
# ['health'] <<< ['dentist', 'health', 'health']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['health'] <<< ['dentist', 'health', 'health']
# ['restaurant'] <<< ['bowling_alley', 'bar', 'home_goods_store', 'store']
# ['political'] <<< ['locality', 'political']
# ['beauty_salon'] <<< ['beauty_salon']
# NoCategoryMatched <<< ['police']
# ['WORK'] <<< ['WORK']
# ['hair_care'] <<< ['hair_care']
# ['convenience_store'] <<< ['gas_station', 'convenience_store', 'cafe', 'food', 'store']
# ['convenience_store'] <<< ['gas_station']
# ['real_estate_agency'] <<< ['real_estate_agency', 'dentist', 'doctor', 'health', 'furniture_store', 'home_goods_store', 'store']
# ['store'] <<< ['car_repair']
# ['political'] <<< ['locality', 'political']
# ['HOME'] <<< ['HOME']
# ['store'] <<< ['store']
# ['restaurant'] <<< ['restaurant', 'food']
# ['hair_care'] <<< ['hair_care']
# ['liquor_store'] <<< ['liquor_store', 'convenience_store', 'restaurant', 'food', 'store']
# ['hair_care'] <<< ['hair_care']
# ['bakery'] <<< ['bakery', 'food', 'store']
# ['HOME'] <<< ['HOME']
# ['school'] <<< ['school']
# ['health'] <<< ['dentist', 'health', 'health']
# ['transit_station'] <<< ['bus_station', 'transit_station']
# ['HOME'] <<< ['HOME']
# ['political'] <<< ['locality', 'political']
# ['political'] <<< ['locality', 'political']
# NoCategoryMatched <<< ['police']
# ['HOME'] <<< ['HOME']
# ['health'] <<< ['dentist', 'health', 'health']
# ['finance'] <<< ['post_office', 'finance']
# ['real_estate_agency'] <<< ['real_estate_agency', 'dentist', 'doctor', 'health', 'furniture_store', 'home_goods_store', 'store']
# ['political'] <<< ['locality', 'political']
# ['WORK'] <<< ['WORK']
# ['hair_care'] <<< ['hair_care']
# ['finance'] <<< ['bank', 'finance']
# ['hair_care'] <<< ['hair_care']
# ['school'] <<< ['school']
# ['WORK'] <<< ['WORK']
# ['hair_care'] <<< ['hair_care']
# ['lodging'] <<< ['lodging']
# ['HOME'] <<< ['HOME']
# ['political'] <<< ['locality', 'political']
# ['lodging'] <<< ['campground', 'park', 'lodging']
# NoCategoryMatched <<< ['car_wash']
# ['WORK'] <<< ['WORK']
# ['store'] <<< ['car_repair']
# ['beauty_salon'] <<< ['beauty_salon']
# ['store'] <<< ['moving_company', 'storage']

# %%
categ_mapper.map_categ(['cafe', 'food', 'bakery', 'food', 'store'], logs=True)
# Out:
# ---
# TYPES : ['cafe', 'food', 'bakery', 'food', 'store']
#
# MAPPED: ['cafe', 'store', 'bakery', 'store', 'store']
# most_frequent: ['store']
# most_specific: cafe
# chosen method: most_specific
# 'cafe'

# %%
len(pd.DataFrame(mapped_types))
# Out:
# 41819

# %%
"aaabaa".replace("b", "x")
# Out:
# 'aaaxaa'

# %%
def search_categ_by_types(types, mapped_types=mapped_types):
    types_str = str(types)
    types_str = types_str.replace("\"", "\'")
    
    df = pd.DataFrame(mapped_types)
    df["types"] = df["types"].astype(str).str.replace("\"", "\'")
    
    return df[df["types"] == types_str].drop_duplicates()

# %%
search_categ_by_types(['liquor_store', 'food', 'store'])
# Out:
#          category                              types
# 479  liquor_store  ['liquor_store', 'food', 'store']

# %%
for types in ['liquor_store', 'food', 'store'], ['bus_station', 'transit_station'], ['HOME'], ['museum', 'insurance_agency', 'finance', 'finance'],['parking'],['airport'],['place_of_worship'],['HOME']:
    print("types:", types)
    
    if types == ["WORK"] or types == ["HOME"]:
        print("category:", types)
    else:
        categ = search_categ_by_types(types)["category"]
        if len(categ) == 0:
            print("category:", "NOT FOUND")
        else:
            print("category:", categ)
    
    print()
# Out:
# types: ['liquor_store', 'food', 'store']
# category: 479    liquor_store
# Name: category, dtype: object
#
# types: ['bus_station', 'transit_station']
# category: 12    transit_station
# Name: category, dtype: object
#
# types: ['HOME']
# category: ['HOME']
#
# types: ['museum', 'insurance_agency', 'finance', 'finance']
# category: NOT FOUND
#
# types: ['parking']
# category: 24    bar
# Name: category, dtype: object
#
# types: ['airport']
# category: 11832    NoCategoryMatched
# Name: category, dtype: object
#
# types: ['place_of_worship']
# category: 74    place_of_worship
# Name: category, dtype: object
#
# types: ['HOME']
# category: ['HOME']

# %%
search_categ_by_types(['museum', 'insurance_agency', 'finance'])
# Out:
# Empty DataFrame
# Columns: [category, types]
# Index: []

# %%
srg = objects_dao.load_stop_region_group_object("6015")

# %%
srg.sequence_report().head()
# Out:
#    delta_t_from_last_sr  distance  \
# 0               97363.0   27957.2
# 1                4438.0    1068.4
# 2             1387462.0    1238.6
# 3                3391.0    1105.0
# 4                  50.0      86.1
#
#                                         last_sr_type  \
# 0                                        [[airport]]
# 1                      [[liquor_store, food, store]]
# 2                   [[bus_station, transit_station]]
# 3                                      [[hair_care]]
# 4  [[museum], [insurance_agency, finance], [finan...
#
#                                              sr_type last_sr_semantics  \
# 0                      [[liquor_store, food, store]]            [WORK]
# 1                   [[bus_station, transit_station]]                []
# 2                                      [[hair_care]]                []
# 3  [[museum], [insurance_agency, finance], [finan...            [HOME]
# 4                                        [[parking]]                []
#
#   sr_semantics     last_sr          sr  \
# 0           []  agg_6015_0      6015_3
# 1           []      6015_3      6015_4
# 2       [HOME]      6015_4  agg_6015_5
# 3           []  agg_6015_5      6015_7
# 4           []      6015_7      6015_8
#
#                                            tags  \
# 0                   [liquor_store, food, store]
# 1                [bus_station, transit_station]
# 2                                        [HOME]
# 3  [museum, insurance_agency, finance, finance]
# 4                                     [parking]
#
#                                       last_tags
# 0                                        [WORK]
# 1                   [liquor_store, food, store]
# 2                [bus_station, transit_station]
# 3                                        [HOME]
# 4  [museum, insurance_agency, finance, finance]

# %%
srg.search_stop_region_by_id("6015_7").load_close_pois()
# Out:
#                                             name                     place_id  \
# 22                               JPF Instruments  ChIJpUBZuz8fj0cR57dcqc6HOT4
# 5            Zurich, Agence Generale Roger Besse  ChIJLTkT9Q4fj0cRkYAyM5r6tS8
# 28                        Zurich Suisse - Agence  ChIJzQvj9A4fj0cRo9o_gZozQzM
# 19                        Cinémas de Sierre Sàrl  ChIJFzF88Q4fj0cRGLh_baDoGvc
# 11                                         Bourg  ChIJFzF88Q4fj0cRk9ftb643Ygg
# 14                          Coop Vitality Sierre  ChIJS9p9WA4fj0cRHURY-5mHZ18
# 25                         Soho Lounge Café Sàrl  ChIJFzF88Q4fj0cRKULITUZaG6o
# 9                        Coop Supermarché Sierre  ChIJkSj7Ww4fj0cRLiKQgoGv7co
# 2                                Roland Burgener  ChIJ8zSC7Q4fj0cRwU3lhjzrPZA
# 17                  CSS Assurance, Agence Sierre  ChIJJer97Q4fj0cRDVeR1oY_Ack
# 12                         Véronique Crescentino  ChIJ8zSC7Q4fj0cR_Uie7dZCA0s
# 24                           Jean Pierre Zwissig  ChIJ8zSC7Q4fj0cRQZBeZdSBCSw
# 29                 Vidômes Coiffure de Tina Foti  ChIJFx9vXw4fj0cRuCSdv1qIUnw
# 3                Mrs. Gabrielle Bünter Podologue  ChIJFx9vXw4fj0cRAvdvXvvuQ-4
# 15                        Institut Vanessa Besse  ChIJUbAVXw4fj0cRBuGEEOdEkq0
# 13                                   Le Comptoir  ChIJ-UE6chwfj0cRiHO3sS4AToY
# 7                                 Banque Cler SA  ChIJtZsOzA4fj0cRpQcrk9jHglE
# 16                                     Le Trèfle  ChIJ6TIlYA4fj0cRD04pDFrNdZk
# 4                                     Le Bistrot  ChIJ6TIlYA4fj0cR7YWawJiC_U4
# 26                             Hôtel de la Poste  ChIJ4106YA4fj0cRKB_Hs0yUy00
# 27                  Institut de beauté Beaubourg  ChIJ8zSC7Q4fj0cRlovW4kFAV5E
# 21    Gérard Zwissig, Belle Résidence Immobilier  ChIJ8zSC7Q4fj0cRg6feE1RQEWQ
# 20                                  AZ SPORTS SA  ChIJWXWo7A4fj0cRkzxitLB2ULc
# 10                        Coop Restaurant Sierre  ChIJDbTo9w4fj0cRYroRojNp_9Y
# 23  Helvetia Assurances Agence principale Sierre  ChIJddaI9w4fj0cRmnt9GoXh9rw
# 6                              Kiosque du Centre  ChIJb_929g4fj0cROSbbhLds_uE
# 0                                        Le 3960  ChIJI-hiPIQfj0cRyfs74XUeUyU
# 8                 Administration Ville de Sierre  ChIJNTGLkw4fj0cR3Y0VrQnAJc8
# 18                          Casa Portuguêsa 2000  ChIJM-UI6w4fj0cRXRhVnODaQ8w
# 1                         Trattoria della Piazza  ChIJB0kz7w4fj0cRSiE8u4ubSMA
#
#                                             plus_code  price_level  rating  \
# 22  {'compound_code': '7GVM+CR Sierre, Switzerland...          NaN     NaN
# 5   {'compound_code': '7GVM+CR Sierre, Switzerland...          NaN     3.5
# 28  {'compound_code': '7GVM+CR Sierre, Switzerland...          NaN     NaN
# 19  {'compound_code': '7GVM+GP Sierre, Switzerland...          NaN     5.0
# 11  {'compound_code': '7GVM+GP Sierre, Switzerland...          NaN     4.2
# 14  {'compound_code': '7GVM+GQ Sierre, Switzerland...          NaN     4.1
# 25  {'compound_code': '7GVM+FJ Sierre, Switzerland...          NaN     4.1
# 9   {'compound_code': '7GVM+HP Sierre, Switzerland...          NaN     4.2
# 2   {'compound_code': '7GVM+GJ Sierre, Switzerland...          NaN     3.7
# 17  {'compound_code': '7GVM+GJ Sierre, Switzerland...          NaN     5.0
# 12  {'compound_code': '7GVM+GJ Sierre, Switzerland...          NaN     5.0
# 24  {'compound_code': '7GVM+FJ Sierre, Switzerland...          NaN     NaN
# 29  {'compound_code': '7GVM+FW Sierre, Switzerland...          NaN     NaN
# 3   {'compound_code': '7GVM+FW Sierre, Switzerland...          NaN     NaN
# 15  {'compound_code': '7GVM+CX Sierre, Switzerland...          NaN     5.0
# 13  {'compound_code': '7GVM+8Q Sierre, Switzerland...          NaN     4.7
# 7   {'compound_code': '7GVM+HQ Sierre, Switzerland...          NaN     3.0
# 16  {'compound_code': '7GVM+8W Sierre, Switzerland...          NaN     4.0
# 4   {'compound_code': '7GVM+8W Sierre, Switzerland...          NaN     NaN
# 26  {'compound_code': '7GVM+8W Sierre, Switzerland...          NaN     4.3
# 27  {'compound_code': '7GVM+FH Sierre, Switzerland...          NaN     NaN
# 21  {'compound_code': '7GVM+FH Sierre, Switzerland...          NaN     NaN
# 20  {'compound_code': '7GVM+GH Sierre, Switzerland...          NaN     4.9
# 10  {'compound_code': '7GVM+JV Sierre, Switzerland...          NaN     4.1
# 23  {'compound_code': '7GVM+HW Sierre, Switzerland...          NaN     NaN
# 6   {'compound_code': '7GVM+9G Sierre, Switzerland...          NaN     3.0
# 0   {'compound_code': '7GVM+CF Sierre, Switzerland...          NaN     4.8
# 8   {'compound_code': '7GVM+6M Sierre, Switzerland...          NaN     5.0
# 18  {'compound_code': '7GVM+FF Sierre, Switzerland...          NaN     3.7
# 1   {'compound_code': '7GVM+HG Sierre, Switzerland...          2.0     4.2
#
#                                                 types  user_ratings_total  \
# 22         [museum, point_of_interest, establishment]                 NaN
# 5   [insurance_agency, finance, point_of_interest,...                 2.0
# 28        [finance, point_of_interest, establishment]                 NaN
# 19  [movie_theater, point_of_interest, establishment]                 1.0
# 11  [movie_theater, point_of_interest, establishment]                49.0
# 14  [pharmacy, health, store, point_of_interest, e...                 8.0
# 25     [cafe, food, point_of_interest, establishment]                95.0
# 9   [grocery_or_supermarket, food, store, point_of...               214.0
# 2   [doctor, health, point_of_interest, establishm...                 3.0
# 17  [insurance_agency, health, point_of_interest, ...                 4.0
# 12  [doctor, health, point_of_interest, establishm...                 1.0
# 24  [real_estate_agency, point_of_interest, establ...                 NaN
# 29      [hair_care, point_of_interest, establishment]                 NaN
# 3    [beauty_salon, point_of_interest, establishment]                 NaN
# 15   [beauty_salon, point_of_interest, establishment]                 3.0
# 13            [bar, point_of_interest, establishment]                15.0
# 7    [atm, finance, point_of_interest, establishment]                 1.0
# 16  [restaurant, food, point_of_interest, establis...                 2.0
# 4   [restaurant, food, point_of_interest, establis...                 NaN
# 26  [restaurant, food, lodging, point_of_interest,...               103.0
# 27   [beauty_salon, point_of_interest, establishment]                 NaN
# 21  [real_estate_agency, point_of_interest, establ...                 NaN
# 20          [store, point_of_interest, establishment]                13.0
# 10  [restaurant, food, point_of_interest, establis...               120.0
# 23  [insurance_agency, point_of_interest, establis...                 NaN
# 6           [store, point_of_interest, establishment]                 1.0
# 0             [bar, point_of_interest, establishment]                31.0
# 8   [point_of_interest, local_government_office, e...                 2.0
# 18  [grocery_or_supermarket, food, store, point_of...                17.0
# 1   [restaurant, food, point_of_interest, establis...                72.0
#
#                                vicinity   latitude  longitude   distance  \
# 22           Avenue Max Huber 2, Sierre  46.293526   7.534571  13.021041
# 5            Avenue Max Huber 2, Sierre  46.293526   7.534571  13.021041
# 28           Avenue Max Huber 2, Sierre  46.293526   7.534571  13.021041
# 19           Avenue Max Huber 1, Sierre  46.293758   7.534314  20.067624
# 11           Avenue Max Huber 1, Sierre  46.293758   7.534314  20.067624
# 14           Avenue Max Huber 7, Sierre  46.293837   7.534488  26.602576
# 25           Avenue Max Huber 1, Sierre  46.293642   7.534058  29.802015
# 9            Avenue Max Huber 6, Sierre  46.293876   7.534335  31.728198
# 2           Avenue du Château 4, Sierre  46.293752   7.534079  32.545304
# 17          Avenue du Château 4, Sierre  46.293752   7.534079  32.545304
# 12          Avenue du Château 4, Sierre  46.293752   7.534079  32.545304
# 24          Avenue du Château 4, Sierre  46.293720   7.534052  32.737093
# 29              Rue du Bourg 27, Sierre  46.293625   7.534872  33.402496
# 3               Rue du Bourg 27, Sierre  46.293625   7.534872  33.402496
# 15           Avenue Max Huber 2, Sierre  46.293619   7.534897  35.276293
# 13              Rue du Bourg 16, Sierre  46.293284   7.534393  35.311823
# 7            Avenue Max Huber 6, Sierre  46.293939   7.534489  37.870916
# 16              Rue du Bourg 22, Sierre  46.293304   7.534753  40.794954
# 4               Rue du Bourg 22, Sierre  46.293304   7.534753  40.794954
# 26              Rue du Bourg 22, Sierre  46.293301   7.534765  41.614159
# 27          Avenue du Château 4, Sierre  46.293686   7.533887  43.669201
# 21          Avenue du Château 4, Sierre  46.293686   7.533887  43.669201
# 20          Avenue du Château 4, Sierre  46.293788   7.533942  43.693540
# 10           Avenue Max Huber 3, Sierre  46.294016   7.534694  50.212508
# 23  Rue Notre Dame des Marais 1, Sierre  46.293994   7.534767  50.526453
# 6               Rue du Bourg 17, Sierre  46.293444   7.533772  54.313679
# 0           Avenue du Château 1, Sierre  46.293534   7.533723  55.731699
# 8       Place de Hôtel de ville, Sierre  46.293097   7.534158  59.985809
# 18          Avenue du Château 3, Sierre  46.293646   7.533634  62.314476
# 1           Avenue du Château 6, Sierre  46.293965   7.533802  63.739763
#
#     position   sr_id
# 22         0  6015_7
# 5          2  6015_7
# 28         1  6015_7
# 19         3  6015_7
# 11         4  6015_7
# 14         5  6015_7
# 25         6  6015_7
# 9          7  6015_7
# 2         10  6015_7
# 17         8  6015_7
# 12         9  6015_7
# 24        11  6015_7
# 29        12  6015_7
# 3         13  6015_7
# 15        14  6015_7
# 13        15  6015_7
# 7         16  6015_7
# 16        18  6015_7
# 4         17  6015_7
# 26        19  6015_7
# 27        21  6015_7
# 21        20  6015_7
# 20        22  6015_7
# 10        23  6015_7
# 23        24  6015_7
# 6         25  6015_7
# 0         26  6015_7
# 8         27  6015_7
# 18        28  6015_7
# 1         29  6015_7
