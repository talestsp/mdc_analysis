# %%
import pandas as pd
import os

import matplotlib.pyplot as plt

from bokeh.plotting import figure
from bokeh.io import output_notebook, show
from bokeh.layouts import gridplot

output_notebook()

os.chdir("/home/tales/dev/master/mdc_analysis/")
print("working dir", os.getcwd())

import gc
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fe24c2e2-4ba1-4ca3-9eaa-37a703456ad2">Loading BokehJS ...</span>
#     </div>
# working dir /home/tales/dev/master/mdc_analysis

# %%
data = pd.read_csv("/home/tales/dev/master/hot_osm_analysis/planet_osm_point_3.csv", sep="{")
data = data.set_index("osm_id")
print(len(data))
data.sample(6)
# Out:
# /home/tales/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,1,2,4,6,7,9,11,13,14,17,18,20,22,23,25,26,27,30,31,32,33,35,37,38,39,41,45,48,50,51,52,54,55,57,58,61,62,63,64,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 314877
#            access addr:housename addr:housenumber addr:interpolation  \
# osm_id
# 3592247317    NaN            NaN                2                NaN
# 5859724050    NaN            NaN              NaN                NaN
# 2692752198    NaN            NaN                2                NaN
# 1327845533    NaN            NaN              NaN                NaN
# 703390222     NaN            NaN              NaN                NaN
# 3729805185    NaN            NaN              NaN                NaN
#
#             admin_level aerialway aeroway amenity area barrier  \
# osm_id
# 3592247317          NaN       NaN     NaN     NaN  NaN     NaN
# 5859724050          NaN       NaN     NaN     NaN  NaN     NaN
# 2692752198          NaN       NaN     NaN     NaN  NaN     NaN
# 1327845533          NaN       NaN     NaN     NaN  NaN     NaN
# 703390222           NaN       NaN     NaN     NaN  NaN     NaN
# 3729805185          NaN       NaN     NaN     NaN  NaN     NaN
#
#                                   ...                              tourism  \
# osm_id                            ...
# 3592247317                        ...                                  NaN
# 5859724050                        ...                                  NaN
# 2692752198                        ...                                  NaN
# 1327845533                        ...                                  NaN
# 703390222                         ...                          picnic_site
# 3729805185                        ...                                  NaN
#
#            tower:type tunnel water waterway  wetland width wood  z_order  \
# osm_id
# 3592247317        NaN    NaN   NaN      NaN      NaN   NaN  NaN      NaN
# 5859724050        NaN    NaN   NaN      NaN      NaN   NaN  NaN      NaN
# 2692752198        NaN    NaN   NaN      NaN      NaN   NaN  NaN      NaN
# 1327845533        NaN    NaN   NaN      NaN      NaN   NaN  NaN      NaN
# 703390222         NaN    NaN   NaN      NaN      NaN   NaN  NaN      NaN
# 3729805185        NaN    NaN   NaN      NaN      NaN   NaN  NaN      NaN
#
#                                                           way
# osm_id
# 3592247317  010100002031BF0D00A4703D0A0AD0294185EB5158AE03...
# 5859724050  010100002031BF0D00EC51B8DEDC003041D7A370DD59FA...
# 2692752198  010100002031BF0D009A9999991A62294114AE474179FE...
# 1327845533  010100002031BF0D001F85EB5165D53041F6285C4F2C20...
# 703390222   010100002031BF0D0048E17A146CA12B415C8FC27541FA...
# 3729805185  010100002031BF0D007B14AE476AAA2A411F85EB71ECBC...
#
# [6 rows x 69 columns]

# %% [markdown]
# # Looking for places' type

# %% [markdown]
# Can't find places such as "park" in amenity column

# %%
def 

print(data["leisure"].value_counts().head(10))
f, ax = plt.subplots(figsize=(15,5))
data["leisure"].value_counts().head(25).plot.bar(title="Frequency of point LEISURE")

# %%
valid_values = []

for column in data.columns.tolist():
    valid_values.append({"column": column, "valid_values": data[column].count()})

# %%
valid_values = pd.DataFrame(valid_values).sort_values(by="valid_values", ascending=False)
valid_values["prop"] = round(valid_values["valid_values"] / len(data), 3)
valid_values.head(10)
# Out:
#               column  valid_values   prop
# 68               way        314875  1.000
# 2   addr:housenumber        129968  0.413
# 39              name        118930  0.378
# 59           tourism         62449  0.198
# 7            amenity         55267  0.176
# 55              shop         39458  0.125
# 43          operator         31350  0.100
# 51               ref         26278  0.083
# 22               ele         18508  0.059
# 28          historic         10554  0.034

# %% [markdown]
# ### Leisure

# %%
data["leisure"].value_counts().plot.bar()

# %%
# Out:
# fitness_station    931
# pitch              883
# sports_centre      469
# firepit            159
# swimming_pool      128
# park               110
# fitness_centre      85
# track               46
# picnic_table        37
# slipway             33
# Name: leisure, dtype: int64
