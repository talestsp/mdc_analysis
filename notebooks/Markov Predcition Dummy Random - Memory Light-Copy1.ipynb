# %% [markdown]
# # Markov Prediction

# %%
import os
os.chdir("/home/tales/dev/master/mdc_analysis/")
print("working dir", os.getcwd())
import threading

import src.ml.markov as mk
from src.dao import csv_dao
from src.entity.stop_region import StopRegionGroup, sr_row_to_stop_region
from src.exceptions import exceptions

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Out:
# working dir /home/tales/dev/master/mdc_analysis

# %%
def load_tags_sequence(users, users_tags_sequence_list):
    users_tags_sequence = {}
    print("thread users", users)
    for user_id in users:
        print("Loading user {} data".format(user_id))
        users_tags_sequence[user_id] = StopRegionGroup(csv_dao.stop_region_sequence(user_id), 
                                                        agglutinate_stop_regions=True).sequence_stop_region_tags()["tag"].tolist()
    users_tags_sequence_list.append(users_tags_sequence)
    return users_tags_sequence
    
def users_partitions(users, n):
    users_partitions = []
    partition_size = int(len(users) / n)
    
    for i in range(n):
        partition = users[i * partition_size : (i+1) * partition_size]
        users_partitions.append(partition)
    
    users_partitions[-1] = users_partitions[-1] + users[(i+1) * partition_size:]
    
    return users_partitions
    
def load_tags_sequence_threads(users, n_threads):
    users_tags_sequence_list = []
    threads = []
    
    for partition in users_partitions(users, n_threads):
        users_tags_sequence = {}
        
        print("partition", partition)
        
        t = threading.Thread(target=load_tags_sequence, 
                             args=(partition, users_tags_sequence_list))
        
        t.start()
        threads.append(t)
        
    for t in threads:
        t.join()
    
    for r in users_tags_sequence_list:
        print(r)
        
def join_dicts(dict_list):
    final_dict = dict_list[0]    
    for another_dict in dict_list[1:]:
        final_dict = {**final_dict, **another_dict}
    return final_dict

def load_single_thread(users):
    return load_tags_sequence(users, [])

# %%
users = os.listdir("outputs/stop_regions/")[0:4]

users = ["5938", "5973", "5928", "5927", "5993", "6177"]

print(users, "\n")
r = load_tags_sequence_threads(users, 2)
print(len(join_dicts.keys()))
# Out:
# ['5938', '5973', '5928', '5927', '5993', '6177']
#
# partition ['5938', '5973', '5928']
# thread users ['5938', '5973', '5928']
# Loading user 5938 data
# partition ['5927', '5993', '6177']
# thread users ['5927', '5993', '6177']
# Loading user 5927 data
# Loading user 5993 data
# Loading user 5973 data
# Loading user 6177 data
# Loading user 5928 data
# {'5927': [['beauty_salon'], ['store'], ['real_estate_agency', 'travel_agency'], ['finance'], ['HOME'], ['beauty_salon'], ['HOME'], ['store'], ['finance'], ['finance'], ['gas_station', 'atm', 'convenience_store', 'finance', 'food', 'store'], ['HOME'], ['library', 'library'], ['HOME'], ['restaurant', 'food'], ['lodging', 'restaurant', 'food', 'lodging'], ['locality', 'political'], ['locality', 'political'], ['locality', 'political'], ['locality', 'political'], ['store'], ['HOME'], ['store'], ['HOME'], ['beauty_salon'], ['HOME'], ['beauty_salon'], ['HOME'], ['beauty_salon'], ['HOME'], ['locality', 'political'], ['health', 'finance'], ['health', 'school'], ['restaurant', 'food', 'electrician'], ['liquor_store', 'food', 'store'], ['locality', 'political'], ['locality', 'political'], ['school'], ['locality', 'political'], ['locality', 'political'], ['HOME'], ['library', 'library'], ['HOME'], ['store'], ['real_estate_agency', 'travel_agency'], ['HOME'], ['pharmacy', 'health', 'store'], ['atm', 'finance'], ['florist', 'store'], ['HOME'], ['store'], ['beauty_salon'], ['store'], ['liquor_store', 'convenience_store', 'restaurant', 'food', 'store'], ['finance', 'health'], ['locality', 'political'], ['HOME'], ['beauty_salon'], ['HOME'], ['library', 'library'], ['HOME'], ['store'], ['HOME'], ['store'], ['HOME'], ['beauty_salon'], ['store'], ['HOME'], ['beauty_salon'], ['HOME'], ['store'], ['doctor', 'health', 'doctor', 'health'], ['health', 'finance'], ['store'], ['HOME'], ['car_repair'], ['store'], ['locality', 'political'], ['store'], ['HOME'], ['beauty_salon'], ['real_estate_agency', 'travel_agency'], ['HOME'], ['beauty_salon'], ['HOME'], ['store'], ['real_estate_agency', 'travel_agency'], ['health', 'finance'], ['car_rental', 'bakery', 'food', 'store'], ['cafe', 'food'], ['cafe', 'food'], ['store'], ['HOME'], ['library', 'library'], ['HOME'], ['beauty_salon'], ['store'], ['HOME'], ['store'], ['locality', 'political'], ['gas_station'], ['locality', 'political'], ['locality', 'political'], ['locality', 'political'], ['locality', 'political'], ['locality', 'political'], ['locality', 'political'], ['school'], ['locality', 'political'], ['locality', 'political'], ['locality', 'political'], ['health'], ['health', 'real_estate_agency'], ['locality', 'political'], ['locality', 'political'], ['locality', 'political'], ['locality', 'political'], ['school'], ['liquor_store', 'food', 'store'], ['clothing_store', 'store'], ['cafe', 'food'], ['HOME'], ['meal_takeaway', 'restaurant', 'food'], ['HOME'], ['beauty_salon'], ['HOME'], ['store'], ['beauty_salon'], ['store'], ['locality', 'political'], ['restaurant', 'food', 'atm', 'finance', 'finance', 'doctor', 'health'], ['HOME'], ['parking'], ['store'], ['grocery_or_supermarket', 'supermarket', 'food', 'store'], ['real_estate_agency'], ['travel_agency'], ['car_rental', 'bakery', 'food', 'store'], ['health', 'school'], ['finance'], ['HOME'], ['store'], ['HOME'], ['transit_station'], ['bus_station', 'transit_station'], ['finance'], ['HOME'], ['store'], ['finance', 'health'], ['clothing_store', 'store'], ['doctor', 'health', 'store'], ['church', 'place_of_worship'], ['hair_care'], ['liquor_store', 'food', 'store'], ['cafe', 'food'], ['HOME'], ['beauty_salon'], ['school'], ['beauty_salon'], ['transit_station', 'bus_station', 'subway_station'], ['store'], ['real_estate_agency', 'travel_agency'], ['health'], ['real_estate_agency', 'travel_agency'], ['health'], ['real_estate_agency', 'travel_agency'], ['bus_station', 'transit_station'], ['HOME'], ['store'], ['stadium'], ['HOME'], ['library', 'library'], ['HOME'], ['store'], ['doctor', 'health'], ['school'], ['restaurant', 'food', 'electrician'], ['store'], ['HOME'], ['beauty_salon'], ['HOME'], ['beauty_salon'], ['health', 'school'], ['restaurant', 'food', 'electrician'], ['car_rental', 'bakery', 'food', 'store'], ['finance'], ['grocery_or_supermarket', 'supermarket', 'food', 'store'], ['liquor_store', 'convenience_store', 'restaurant', 'food', 'store'], ['unive ...
# {'5938': [['HOME'], ['school'], ['restaurant', 'food'], ['gas_station', 'convenience_store', 'food', 'store'], ['HOME'], ['parking'], ['locality', 'political'], ['locality', 'political'], ['gas_station'], ['HOME'], ['bus_station', 'transit_station'], ['HOME'], ['store', 'store', 'shopping_mall'], ['HOME'], ['restaurant', 'food'], ['hospital'], ['HOME'], ['bakery', 'food', 'store'], ['HOME'], ['bus_station', 'transit_station'], ['HOME'], ['locality', 'political'], ['HOME'], ['school'], ['HOME'], ['restaurant', 'food'], ['HOME'], ['restaurant', 'food'], ['bus_station', 'transit_station'], ['restaurant', 'food'], ['HOME'], ['restaurant', 'food'], ['HOME'], ['health'], ['HOME'], ['beauty_salon'], ['health', 'store'], ['HOME'], ['lodging'], ['clothing_store', 'store'], ['restaurant', 'food'], ['beauty_salon'], ['HOME'], ['health'], ['hair_care', 'health'], ['HOME'], ['locality', 'political'], ['HOME'], ['place_of_worship'], ['HOME'], ['school'], ['locality', 'political'], ['locality', 'political'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['bakery', 'food', 'store'], ['HOME'], ['locality', 'political'], ['bus_station', 'transit_station'], ['HOME'], ['beauty_salon'], ['HOME'], ['accounting', 'finance'], ['hair_care', 'health'], ['WORK'], ['electronics_store', 'home_goods_store', 'store'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['health'], ['HOME'], ['beauty_salon'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['locality', 'political'], ['grocery_or_supermarket', 'food', 'store'], ['restaurant', 'meal_takeaway', 'cafe', 'food'], ['locality', 'political'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['locality', 'political'], ['HOME'], ['WORK'], ['pharmacy', 'health', 'store'], ['bakery', 'food', 'store', 'bakery', 'food', 'store', 'hair_care'], ['school'], ['restaurant', 'meal_takeaway', 'cafe', 'food'], ['beauty_salon', 'doctor', 'health', 'food', 'store'], ['car_repair', 'store'], ['school'], ['book_store', 'store'], ['car_repair', 'store'], ['HOME'], ['WORK'], ['HOME'], ['real_estate_agency'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['locality', 'political'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['gym', 'health'], ['HOME'], ['beauty_salon'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['campground', 'park', 'lodging'], ['HOME'], ['car_repair', 'restaurant', 'food'], ['HOME'], ['beauty_salon'], ['HOME'], ['hair_care', 'health'], ['WORK'], ['HOME'], ['WORK'], ['locality', 'political'], ['HOME'], ['WORK'], ['supermarket', 'grocery_or_supermarket', 'food', 'store'], ['restaurant', 'food'], ['general_contractor'], ['church', 'place_of_worship'], ['jewelry_store', 'store'], ['HOME'], ['WORK'], ['HOME'], ['beauty_salon'], ['HOME'], ['WORK'], ['grocery_or_supermarket', 'supermarket', 'food', 'store'], ['HOME'], ['WORK'], ['locality', 'political'], ['HOME'], ['school'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['car_repair'], ['store', 'store', 'shopping_mall'], ['WORK'], ['beauty_salon'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['WORK'], ['locksmith', 'store'], ['furniture_store', 'laundry', 'home_goods_store', 'store', 'general_contractor'], ['beauty_salon'], ['HOME'], ['hair_care', 'health'], ['WORK'], ['HOME'], ['WORK'], ['HOME'], ['store', 'store', 'shopping_mall'], ['WORK'], ['bus_station', 'transit_station'], ['HOME'], ['supermarket', 'grocery_or_supermarket', 'food', 'store'], ['HOME'], ['beauty_salon'], ['WORK'], ['school'], ['food', 'beauty_salon', 'doctor', 'health', 'beauty_salon', 'hair_care', 'doctor', 'health'], ['jewelry_store', 'store'], ['school'], ['hair_care', 'bakery', 'food', 'store', 'bakery', 'food', 'store'], ['car_repair', 'store'], ['restaurant', 'food'], ['WORK'], ['bakery', 'cafe', 'restaurant', 'food', 'store'], ['HOME'], ['restaurant', 'food'], ['HOME'], ['beauty_salon'], ['HOME'], ['grocery_or_supermarket', 'food', 'store'], ['WORK'], ['HOME'], ['WORK'], ['bus_station', 'transit_s ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e048a82cbdf1> in <module>()
#       5 print(users, "\n")
#       6 r = load_tags_sequence_threads(users, 2)
# ----> 7 print(len(join_dicts.keys()))
#
# AttributeError: 'function' object has no attribute 'keys'

# %% [markdown]
# ## Loading Data

# %%
users_tags_sequence = {}

users = os.listdir("outputs/stop_regions/")

for user_id in users:
    print("Loading user {} data".format(user_id))
    users_tags_sequence[user_id] = StopRegionGroup(csv_dao.stop_region_sequence(user_id), 
                                                    agglutinate_stop_regions=True).sequence_stop_region_tags()["tag"].tolist()

# %% [markdown]
# ## Evaluation

# %%
from src.experiments.markov_chain import evaluation_markov_k_fold_light_mem, all_users_vs_one_light_mem

# %%
for user_id in users_tags_sequence.keys():
    print(user_id)
    
    tags_sequence = users_tags_sequence[user_id]
    
    k=5
    try:
        evaluation_markov_k_fold_light_mem(tags_sequence, user_id=user_id, k=k, distributive_tags=False)
        evaluation_markov_k_fold_light_mem(tags_sequence, user_id=user_id, k=k, distributive_tags=True)
        
        evaluation_markov_k_fold_light_mem(tags_sequence, user_id=user_id, k=k, distributive_tags=False, random_dummy_mode="EQUAL_DESTINATION_PROBA")
        evaluation_markov_k_fold_light_mem(tags_sequence, user_id=user_id, k=k, distributive_tags=True, random_dummy_mode="EQUAL_DESTINATION_PROBA")
        
    except exceptions.TagsLengthNeedsToBeGreaterThanK:
        print("TagsLengthNeedsToBeGreaterThanK")

# %%
all_users_vs_one_light_mem(users_tags_sequence, distributive_tags=False)

# %%
all_users_vs_one_light_mem(users_tags_sequence, distributive_tags=True)

# %%
all_users_vs_one_light_mem(users_tags_sequence, distributive_tags=False, random_dummy_mode="EQUAL_DESTINATION_PROBA")

# %%
all_users_vs_one_light_mem(users_tags_sequence, distributive_tags=True, random_dummy_mode="EQUAL_DESTINATION_PROBA")
